# %% [markdown]
# # Developing an AI application
#
# Going forward, AI algorithms will be incorporated into more and more everyday applications. For example, you might want to include an image classifier in a smart phone app. To do this, you'd use a deep learning model trained on hundreds of thousands of images as part of the overall application architecture. A large part of software development in the future will be using these types of models as common parts of applications.
#
# In this project, you'll train an image classifier to recognize different species of flowers. You can imagine using something like this in a phone app that tells you the name of the flower your camera is looking at. In practice you'd train this classifier, then export it for use in your application. We'll be using [this dataset](http://www.robots.ox.ac.uk/~vgg/data/flowers/102/index.html) of 102 flower categories, you can see a few examples below.
#
# <img src='assets/Flowers.png' width=500px>
#
# The project is broken down into multiple steps:
#
# * Load and preprocess the image dataset
# * Train the image classifier on your dataset
# * Use the trained classifier to predict image content
#
# We'll lead you through each part which you'll implement in Python.
#
# When you've completed this project, you'll have an application that can be trained on any set of labeled images. Here your network will be learning about flowers and end up as a command line application. But, what you do with your new skills depends on your imagination and effort in building a dataset. For example, imagine an app where you take a picture of a car, it tells you what the make and model is, then looks up information about it. Go build your own dataset and make something new.
#
# First up is importing the packages you'll need. It's good practice to keep all the imports at the beginning of your code. As you work through this notebook and find you need to import a package, make sure to add the import up here.

# %%
# Imports here
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch import nn
from torch import tensor
from torch import optim
import torch.nn.functional as F
from torch.autograd import Variable
from torchvision import datasets, transforms
import torchvision.models as models
import argparse
from collections import OrderedDict
# helper files
import json
import PIL
import seaborn as sns
from PIL import Image
import time
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %% [markdown]
# ## Load the data
#
# Here you'll use `torchvision` to load the data ([documentation](http://pytorch.org/docs/0.3.0/torchvision/index.html)). The data should be included alongside this notebook, otherwise you can [download it here](https://s3.amazonaws.com/content.udacity-data.com/nd089/flower_data.tar.gz). The dataset is split into three parts, training, validation, and testing. For the training, you'll want to apply transformations such as random scaling, cropping, and flipping. This will help the network generalize leading to better performance. You'll also need to make sure the input data is resized to 224x224 pixels as required by the pre-trained networks.
#
# The validation and testing sets are used to measure the model's performance on data it hasn't seen yet. For this you don't want any scaling or rotation transformations, but you'll need to resize then crop the images to the appropriate size.
#
# The pre-trained networks you'll use were trained on the ImageNet dataset where each color channel was normalized separately. For all three sets you'll need to normalize the means and standard deviations of the images to what the network expects. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`, calculated from the ImageNet images.  These values will shift each color channel to be centered at 0 and range from -1 to 1.

# %%
# This was done for training on local PC
# data_dir='/content/flower_data'

#images path
data_dir = 'flowers'
train_dir = data_dir + '/train'
valid_dir = data_dir + '/valid'
test_dir = data_dir + '/test'
# Out:
# True

# %%
## TODO: Define your transforms for the training, validation, and testing sets
data_transforms ={
'training_transforms':transforms.Compose([transforms.RandomRotation(50),
                                       transforms.RandomResizedCrop(224),
                                       transforms.RandomHorizontalFlip(),
                                       transforms.ToTensor(),
                                       transforms.Normalize([0.485, 0.456, 0.406], 
                                                            [0.229, 0.224, 0.225])]),

'testing_transforms': transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], 
                                                           [0.229, 0.224, 0.225])]),

'validation_transforms': transforms.Compose([transforms.Resize(256),
                                      transforms.CenterCrop(224),
                                      transforms.ToTensor(),
                                      transforms.Normalize([0.485, 0.456, 0.406], 
                                                           [0.229, 0.224, 0.225])])}


# TODO: Load the datasets with ImageFolder

image_datasets = {'training_data' : datasets.ImageFolder(train_dir, transform=data_transforms['training_transforms']),
'testing_data' : datasets.ImageFolder(valid_dir, transform=data_transforms['validation_transforms']),
'validation_data' : datasets.ImageFolder(test_dir ,transform = data_transforms['testing_transforms'])
                   }

# TODO: Using the image datasets and the trainforms, define the dataloaders

dataloaders = {'trainingloader' : torch.utils.data.DataLoader(image_datasets['training_data'], batch_size=64, shuffle=True),
'testloader' : torch.utils.data.DataLoader(image_datasets['testing_data'], batch_size=64),
'validationloader' : torch.utils.data.DataLoader(image_datasets['validation_data'], batch_size=64)}

# %% [markdown]
# ### Label mapping
#
# You'll also need to load in a mapping from category label to category name. You can find this in the file `cat_to_name.json`. It's a JSON object which you can read in with the [`json` module](https://docs.python.org/2/library/json.html). This will give you a dictionary mapping the integer encoded categories to the actual names of the flowers.

# %%
import json

with open('cat_to_name.json', 'r') as f:
    cat_to_name = json.load(f)

# %% [markdown]
# # Building and training the classifier
#
# Now that the data is ready, it's time to build and train the classifier. As usual, you should use one of the pretrained models from `torchvision.models` to get the image features. Build and train a new feed-forward classifier using those features.
#
# We're going to leave this part up to you. Refer to [the rubric](https://review.udacity.com/#!/rubrics/1663/view) for guidance on successfully completing this section. Things you'll need to do:
#
# * Load a [pre-trained network](http://pytorch.org/docs/master/torchvision/models.html) (If you need a starting point, the VGG networks work great and are straightforward to use)
# * Define a new, untrained feed-forward network as a classifier, using ReLU activations and dropout
# * Train the classifier layers using backpropagation using the pre-trained network to get the features
# * Track the loss and accuracy on the validation set to determine the best hyperparameters
#
# We've left a cell open for you below, but use as many as you need. Our advice is to break the problem up into smaller parts you can run separately. Check that each part is doing what you expect, then move on to the next. You'll likely find that as you work through each part, you'll need to go back and modify your previous code. This is totally normal!
#
# When training make sure you're updating only the weights of the feed-forward network. You should be able to get the validation accuracy above 70% if you build everything right. Make sure to try different hyperparameters (learning rate, units in the classifier, epochs, etc) to find the best model. Save those hyperparameters to use as default values in the next part of the project.
#
# One last important tip if you're using the workspace to run your code: To avoid having your workspace disconnect during the long-running tasks in this notebook, please read in the earlier page in this lesson called Intro to
# GPU Workspaces about Keeping Your Session Active. You'll want to include code from the workspace_utils.py module.
#
# **Note for Workspace users:** If your network is over 1 GB when saved as a checkpoint, there might be issues with saving backups in your workspace. Typically this happens with wide dense layers after the convolutional layers. If your saved checkpoint is larger than 1 GB (you can open a terminal and check with `ls -lh`), you should reduce the size of your hidden layers and train again.

# %%
# TODO: Build and train your network



# Load pretrained vgg16 Model
#vgg16 have several advantages: It has so many weight parameters, the models are very heavy, 550 MB + of weight size, 
#Which also means long inference time
#source (https://forums.fast.ai/t/vgg-strength-and-limitations/1218)

model = models.vgg16(pretrained=True)

#When a model is loaded in PyTorch, all its parameters have their ‘requires_grad‘ field set to true by default. 
#That means each and every change to the parameter values will be stored in order to be used in the back propagation graph 
#used for training. This increases memory requirements. So,
#since most of the parameters in our pre-trained model are already trained for us, we reset the requires_grad field to false.

#to freeze part of the convolutional part of vgg16 model and train the rest
for param in model.parameters():
    param.requires_grad = False
        
#Then we replace the final layer of the vgg16 model by a small set of Sequential layers. 
#The inputs to the last fully connected layer of vgg16 is fed to a Linear layer, 
#which are then fed into ReLU (rectified linear unit) and Dropout layers.


#Used OrderedDict to preserve the order in which the keys are inserted
from collections import OrderedDict

classifier = nn.Sequential(OrderedDict([
            ('inputs', nn.Linear(25088, 120)), #hidden layer 1 sets output to 120
            ('relu1', nn.ReLU()),
            ('dropout',nn.Dropout(0.501)), #could use a different droupout probability,but 0.5 usually works well
            ('hidden_layer1', nn.Linear(120, 92)), #hidden layer 2 output to 90
            ('relu2',nn.ReLU()),
            ('hidden_layer2',nn.Linear(92,76)), #hidden layer 3 output to 70
            ('relu3',nn.ReLU()),
            ('hidden_layer3',nn.Linear(76,102)),#output size = 102
            ('output', nn.LogSoftmax(dim=1))]))# For using NLLLoss()
   
model.classifier = classifier

if torch.cuda.is_available():
    model.cuda() 

#define the criterion and the optimizer to be used for training.
#Negative Loss Likelihood function(NLLLoss()) as it can be used for classifying multiple classes.
#Adam is one the most popular optimizers because it can adapt the learning rate for each parameter individually.

criterion = nn.NLLLoss()
optimizer = optim.Adam(model.classifier.parameters(), lr=0.00101)

# %%
#Training is carried out for a fixed set of epochs, processing each image once in a single epoch.
#The training data loader loads data in batches.
#In our case, we have given a batch size of 64, which means each batch can have at most 64 images.

#with transfer learning, we need to compute gradients only for a small set of parameters 
#that belong to the few newly added layers towards the end of the model.

#Gradient computation is done using the autograd and back propagation.
#PyTorch accumulates all the gradients in the backward pass. 
# So it is essential to zero them out at the beginning of the training loop.
#This is achieved using the optimizer’s zero_grad function.

#Finally, after the gradients are computed in the backward pass, the parameters are updated using the optimizer’s step function.

#Total loss and accuracy is computed for the whole batch, 
#which is then averaged over all the batches to get the loss and accuracy values for the whole epoch.

epochs=20
for epoch in range(epochs):
    # print("Epoch: {}/{}".format(epoch+1, epochs))
    print(epoch)
     
# tell the model that you are training . So effectively layers like dropout, batchnorm etc,
#which behave different on the train and test procedures know what is going on and hence can behave accordingly.
# Set to training mode    
    # Set to training mode
    model.train()
     
    # Loss and Accuracy within the epoch
    train_loss = 0.0
    train_acc = 0.0
     
    valid_loss = 0.0
    valid_acc = 0.0
 
    device='cuda'
    for i, (inputs, labels) in enumerate(dataloaders['trainingloader']):
 
        inputs = inputs.to(device)
        labels = labels.to(device)
         
        # Clean existing gradients
        optimizer.zero_grad()
         
        # Forward pass - compute outputs on input data using the model
        outputs = model(inputs)
         
        # Compute loss
        loss = criterion(outputs, labels)
         
        # Backpropagate the gradients
        loss.backward()
         
        # Update the parameters
        optimizer.step()
         
        # Compute the total loss for the batch and add it to train_loss
        train_loss += loss.item() * inputs.size(0)
         
        # Compute the accuracy
        ret, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))
         
        # Convert correct_counts to float and then compute the mean
        acc = torch.mean(correct_counts.type(torch.FloatTensor))
         
        # Compute total accuracy in the whole batch and add to train_acc
        train_acc += acc.item() * inputs.size(0)
         
        print("Batch no: {:03d}, Loss on trainig: {:.4f}, Accuracy: {:.4f}".format(i, loss.item(), acc.item()*100))
# Out:
# 0
# Batch no: 000, Loss on trainig: 4.6306, Accuracy: 0.0000
# Batch no: 001, Loss on trainig: 4.6213, Accuracy: 0.0156
# Batch no: 002, Loss on trainig: 4.6025, Accuracy: 0.0000
# Batch no: 003, Loss on trainig: 4.7015, Accuracy: 0.0000
# Batch no: 004, Loss on trainig: 4.6346, Accuracy: 0.0469
# Batch no: 005, Loss on trainig: 4.6002, Accuracy: 0.0469
# Batch no: 006, Loss on trainig: 4.5995, Accuracy: 0.0469
# Batch no: 007, Loss on trainig: 4.6524, Accuracy: 0.0000
# Batch no: 008, Loss on trainig: 4.5943, Accuracy: 0.0312
# Batch no: 009, Loss on trainig: 4.6095, Accuracy: 0.0156
# Batch no: 010, Loss on trainig: 4.5974, Accuracy: 0.0312
# Batch no: 011, Loss on trainig: 4.5047, Accuracy: 0.0625
# Batch no: 012, Loss on trainig: 4.6858, Accuracy: 0.0312
# Batch no: 013, Loss on trainig: 4.4719, Accuracy: 0.0312
# Batch no: 014, Loss on trainig: 4.5086, Accuracy: 0.0469
# Batch no: 015, Loss on trainig: 4.5303, Accuracy: 0.0312
# Batch no: 016, Loss on trainig: 4.4752, Accuracy: 0.0625
# Batch no: 017, Loss on trainig: 4.5057, Accuracy: 0.0312
# Batch no: 018, Loss on trainig: 4.6216, Accuracy: 0.0000
# Batch no: 019, Loss on trainig: 4.5244, Accuracy: 0.0312
# Batch no: 020, Loss on trainig: 4.5084, Accuracy: 0.0781
# Batch no: 021, Loss on trainig: 4.4710, Accuracy: 0.0312
# Batch no: 022, Loss on trainig: 4.5439, Accuracy: 0.0156
# Batch no: 023, Loss on trainig: 4.4074, Accuracy: 0.0938
# Batch no: 024, Loss on trainig: 4.5418, Accuracy: 0.0312
# Batch no: 025, Loss on trainig: 4.5282, Accuracy: 0.0312
# Batch no: 026, Loss on trainig: 4.4705, Accuracy: 0.0156
# Batch no: 027, Loss on trainig: 4.3421, Accuracy: 0.1406
# Batch no: 028, Loss on trainig: 4.3576, Accuracy: 0.0469
# Batch no: 029, Loss on trainig: 4.4453, Accuracy: 0.0938
# Batch no: 030, Loss on trainig: 4.3088, Accuracy: 0.0781
# Batch no: 031, Loss on trainig: 4.4189, Accuracy: 0.0781
# Batch no: 032, Loss on trainig: 4.3329, Accuracy: 0.0625
# Batch no: 033, Loss on trainig: 4.4687, Accuracy: 0.0156
# Batch no: 034, Loss on trainig: 4.2497, Accuracy: 0.1094
# Batch no: 035, Loss on trainig: 4.2970, Accuracy: 0.1250
# Batch no: 036, Loss on trainig: 4.3224, Accuracy: 0.0781
# Batch no: 037, Loss on trainig: 4.3642, Accuracy: 0.0312
# Batch no: 038, Loss on trainig: 4.5120, Accuracy: 0.0469
# Batch no: 039, Loss on trainig: 4.2099, Accuracy: 0.0938
# Batch no: 040, Loss on trainig: 4.2309, Accuracy: 0.0938
# Batch no: 041, Loss on trainig: 4.3386, Accuracy: 0.0156
# Batch no: 042, Loss on trainig: 4.2031, Accuracy: 0.0312
# Batch no: 043, Loss on trainig: 4.2835, Accuracy: 0.0938
# Batch no: 044, Loss on trainig: 4.3391, Accuracy: 0.1094
# Batch no: 045, Loss on trainig: 4.3851, Accuracy: 0.0781
# Batch no: 046, Loss on trainig: 4.3561, Accuracy: 0.0469
# Batch no: 047, Loss on trainig: 4.3123, Accuracy: 0.0625
# Batch no: 048, Loss on trainig: 4.2155, Accuracy: 0.0781
# Batch no: 049, Loss on trainig: 4.3386, Accuracy: 0.0938
# Batch no: 050, Loss on trainig: 4.3152, Accuracy: 0.0938
# Batch no: 051, Loss on trainig: 4.0672, Accuracy: 0.1719
# Batch no: 052, Loss on trainig: 4.3185, Accuracy: 0.0938
# Batch no: 053, Loss on trainig: 4.0559, Accuracy: 0.1094
# Batch no: 054, Loss on trainig: 4.2082, Accuracy: 0.0625
# Batch no: 055, Loss on trainig: 4.2124, Accuracy: 0.0938
# Batch no: 056, Loss on trainig: 4.1370, Accuracy: 0.0938
# Batch no: 057, Loss on trainig: 3.9051, Accuracy: 0.1719
# Batch no: 058, Loss on trainig: 4.0820, Accuracy: 0.0781
# Batch no: 059, Loss on trainig: 3.9989, Accuracy: 0.1406
# Batch no: 060, Loss on trainig: 4.1506, Accuracy: 0.1094
# Batch no: 061, Loss on trainig: 3.8437, Accuracy: 0.1719
# Batch no: 062, Loss on trainig: 4.1359, Accuracy: 0.1250
# Batch no: 063, Loss on trainig: 3.8314, Accuracy: 0.1562
# Batch no: 064, Loss on trainig: 4.0168, Accuracy: 0.1094
# Batch no: 065, Loss on trainig: 4.1056, Accuracy: 0.1094
# Batch no: 066, Loss on trainig: 3.9424, Accuracy: 0.1562
# Batch no: 067, Loss on trainig: 3.8669, Accuracy: 0.1562
# Batch no: 068, Loss on trainig: 4.0102, Accuracy: 0.2031
# Batch no: 069, Loss on trainig: 3.9477, Accuracy: 0.1250
# Batch no: 070, Loss on trainig: 3.9126, Accuracy: 0.1250
# Batch no: 071, Loss on trainig: 3.8590, Accuracy: 0.1406
# Batch no: 072, Loss on trainig: 3.5736, Accuracy: 0.2188
# Batch no: 073, Loss on trainig: 3.6291, Accuracy: 0.2031
# Batch no: 074, Loss on trainig: 3.9735, Accuracy: 0.0625
# Batch no: 075, Loss on trainig: 3.8083, Accuracy: 0.1875
# Batch no: 076, Loss on trainig: 3.6112, Accuracy: 0.1406
# Batch no: 077, Loss on trainig: 3.7119, Accuracy: 0.1562
# Batch no: 078, Loss on trainig: 3.7014, Accuracy: 0.1875
# Batch no: 079, Loss on trainig: 3.3142, Accuracy: 0.2500
# Batch no: 080, Loss on trainig: 3.7169, Accuracy: 0.1875
# Batch no: 081, Loss on trainig: 3.7192, Accuracy: 0.1094
# Batch no: 082, Loss on trainig: 3.5416, Accuracy: 0.2188
# Batch no: 083, Loss on trainig: 3.7362, Accuracy: 0.1094
# Batch no: 084, Loss on trainig: 3.7124, Accuracy: 0.1250
# Batch no: 085, Loss on trainig: 3.4807, Accuracy: 0.1250
# Batch no: 086, Loss on trainig: 3.6895, Accuracy: 0.1406
# Batch no: 087, Loss on trainig: 3.7747, Accuracy: 0.1094
# Batch no: 088, Loss on trainig: 3.4922, Accuracy: 0.1875
# Batch no: 089, Loss on trainig: 3.5360, Accuracy: 0.1406
# Batch no: 090, Loss on trainig: 3.5666, Accuracy: 0.1875
# Batch no: 091, Loss on trainig: 3.4779, Accuracy: 0.2031
# Batch no: 092, Loss on trainig: 3.5167, Accuracy: 0.1719
# Batch no: 093, Loss on trainig: 3.4617, Accuracy: 0.2188
# Batch no: 094, Loss on trainig: 3.6075, Accuracy: 0.2344
# Batch no: 095, Loss on trainig: 3.4811, Accuracy: 0.0781
# Batch no: 096, Loss on trainig: 3.4939, Accuracy: 0.1719
# Batch no: 097, Loss on trainig: 3.7166, Accuracy: 0.1250
# Batch no: 098, Loss on trainig: 3.4207, Accuracy: 0.1875
# Batch no: 099, Loss on trainig: 3.6691, Accuracy: 0.0938
# Batch no: 100, Loss on trainig: 3.2816, Accuracy: 0.1875
# Batch no: 101, Loss on trainig: 3.5521, Accuracy: 0.2344
# Batch no: 102, Loss on trainig: 3.2902, Accuracy: 0.2917
# 1
# Batch no: 000, Loss on trainig: 3.2442, Accuracy: 0.3125
# Batch no: 001, Loss on trainig: 3.5956, Accuracy: 0.2188
# Batch no: 002, Loss on trainig: 3.4207, Accuracy: 0.2031
# Batch no: 003, Loss on trainig: 3.3199, Accuracy: 0.2500
# Batch no: 004, Loss on trainig: 3.2733, Accuracy: 0.2344
# Batch no: 005, Loss on trainig: 3.4149, Accuracy: 0.1719
# Batch no: 006, Loss on trainig: 3.2045, Accuracy: 0.2188
# Batch no: 007, Loss on trainig: 2.9814, Accuracy: 0.2812
# Batch no: 008, Loss on trainig: 3.4635, Accuracy: 0.1406
# Batch no: 009, Loss on trainig: 3.4507, Accuracy: 0.2031
# Batch no: 010, Loss on trainig: 3.0928, Accuracy: 0.2188
# Batch no: 011, Loss on trainig: 3.3364, Accuracy: 0.1719
# Batch no: 012, Loss on trainig: 3.3315, Accuracy: 0.1719
# Batch no: 013, Loss on trainig: 3.4273, Accuracy: 0.1406
# Batch no: 014, Loss on trainig: 3.2301, Accuracy: 0.2188
# Batch no: 015, Loss on trainig: 3.2767, Accuracy: 0.2188
# Batch no: 016, Loss on trainig: 3.1670, Accuracy: 0.2656
# Batch no: 017, Loss on trainig: 3.1748, Accuracy: 0.2344
# Batch no: 018, Loss on trainig: 3.3969, Accuracy: 0.2031
# Batch no: 019, Loss on trainig: 2.8869, Accuracy: 0.2812
# Batch no: 020, Loss on trainig: 3.4666, Accuracy: 0.1406
# Batch no: 021, Loss on trainig: 3.2252, Accuracy: 0.1719
# Batch no: 022, Loss on trainig: 3.0431, Accuracy: 0.2500
# Batch no: 023, Loss on trainig: 2.9198, Accuracy: 0.2344
# Batch no: 024, Loss on trainig: 2.8595, Accuracy: 0.2812
# Batch no: 025, Loss on trainig: 2.9527, Accuracy: 0.2500
# Batch no: 026, Loss on trainig: 2.9029, Accuracy: 0.2812
# Batch no: 027, Loss on trainig: 3.4358, Accuracy: 0.1875
# Batch no: 028, Loss on trainig: 3.0476, Accuracy: 0.1562
# Batch no: 029, Loss on trainig: 3.0909, Accuracy: 0.2969
# Batch no: 030, Loss on trainig: 2.9757, Accuracy: 0.2344
# Batch no: 031, Loss on trainig: 2.5407, Accuracy: 0.3281
# Batch no: 032, Loss on trainig: 2.7403, Accuracy: 0.3125
# Batch no: 033, Loss on trainig: 3.3012, Accuracy: 0.2188
# Batch no: 034, Loss on trainig: 3.2026, Accuracy: 0.2188
# Batch no: 035, Loss on trainig: 2.7870, Accuracy: 0.3438
# Batch no: 036, Loss on trainig: 2.8058, Accuracy: 0.3125
# Batch no: 037, Loss on trainig: 2.8559, Accuracy: 0.2656
# Batch no: 038, Loss on trainig: 2.8995, Accuracy: 0.2656
# Batch no: 039, Loss on trainig: 3.0348, Accuracy: 0.1562
# Batch no: 040, Loss on trainig: 3.1895, Accuracy: 0.2344
# Batch no: 041, Loss on trainig: 2.8200, Accuracy: 0.2500
# Batch no: 042, Loss on trainig: 3.1391, Accuracy: 0.2344
# Batch no: 043, Loss on trainig: 3.0832, Accuracy: 0.2500
# Batch no: 044, Loss on trainig: 2.9206, Accuracy: 0.3438
# Batch no: 045, Loss on trainig: 2.7521, Accuracy: 0.2812
# Batch no: 046, Loss on trainig: 2.7944, Accuracy: 0.2812
# Batch no: 047, Loss on trainig: 2.8510, Accuracy: 0.2812
# Batch no: 048, Loss on trainig: 3.0743, Accuracy: 0.2500
# Batch no: 049, Loss on trainig: 3.1433, Accuracy: 0.2344
# Batch no: 050, Loss on trainig: 2.8472, Accuracy: 0.3750
# Batch no: 051, Loss on trainig: 2.9222, Accuracy: 0.2812
# Batch no: 052, Loss on trainig: 2.8639, Accuracy: 0.2656
# Batch no: 053, Loss on trainig: 3.0118, Accuracy: 0.2500
# Batch no: 054, Loss on trainig: 2.6296, Accuracy: 0.3438
# Batch no: 055, Loss on trainig: 2.7638, Accuracy: 0.3125
# Batch no: 056, Loss on trainig: 2.8616, Accuracy: 0.2500
# Batch no: 057, Loss on trainig: 2.9175, Accuracy: 0.2500
# Batch no: 058, Loss on trainig: 3.1153, Accuracy: 0.2500
# Batch no: 059, Loss on trainig: 3.0169, Accuracy: 0.2188
# Batch no: 060, Loss on trainig: 2.6448, Accuracy: 0.3594
# Batch no: 061, Loss on trainig: 2.6262, Accuracy: 0.3125
# Batch no: 062, Loss on trainig: 2.7335, Accuracy: 0.2969
# Batch no: 063, Loss on trainig: 2.4997, Accuracy: 0.3281
# Batch no: 064, Loss on trainig: 2.8370, Accuracy: 0.2500
# Batch no: 065, Loss on trainig: 2.9195, Accuracy: 0.2969
# Batch no: 066, Loss on trainig: 2.4496, Accuracy: 0.3594
# Batch no: 067, Loss on trainig: 2.9233, Accuracy: 0.2188
# Batch no: 068, Loss on trainig: 3.3147, Accuracy: 0.2031
# Batch no: 069, Loss on trainig: 2.6736, Accuracy: 0.3594
# Batch no: 070, Loss on trainig: 2.8964, Accuracy: 0.2344
# Batch no: 071, Loss on trainig: 2.6764, Accuracy: 0.2500
# Batch no: 072, Loss on trainig: 2.6338, Accuracy: 0.3125
# Batch no: 073, Loss on trainig: 2.8512, Accuracy: 0.2812
# Batch no: 074, Loss on trainig: 2.8931, Accuracy: 0.3594
# Batch no: 075, Loss on trainig: 2.7805, Accuracy: 0.2969
# Batch no: 076, Loss on trainig: 2.8076, Accuracy: 0.2969
# Batch no: 077, Loss on trainig: 2.7782, Accuracy: 0.2656
# Batch no: 078, Loss on trainig: 2.5312, Accuracy: 0.4531
# Batch no: 079, Loss on trainig: 2.7443, Accuracy: 0.3125
# Batch no: 080, Loss on trainig: 2.6941, Accuracy: 0.2969
# Batch no: 081, Loss on trainig: 2.6388, Accuracy: 0.3438
# Batch no: 082, Loss on trainig: 2.7558, Accuracy: 0.2969
# Batch no: 083, Loss on trainig: 2.8766, Accuracy: 0.2656
# Batch no: 084, Loss on trainig: 2.7044, Accuracy: 0.2812
# Batch no: 085, Loss on trainig: 2.7854, Accuracy: 0.2500
# Batch no: 086, Loss on trainig: 2.8227, Accuracy: 0.2812
# Batch no: 087, Loss on trainig: 2.5230, Accuracy: 0.4062
# Batch no: 088, Loss on trainig: 2.4295, Accuracy: 0.3594
# Batch no: 089, Loss on trainig: 2.7840, Accuracy: 0.2969
# Batch no: 090, Loss on trainig: 2.6033, Accuracy: 0.2812
# Batch no: 091, Loss on trainig: 2.9856, Accuracy: 0.2969
# Batch no: 092, Loss on trainig: 2.7682, Accuracy: 0.2812
# Batch no: 093, Loss on trainig: 2.4567, Accuracy: 0.3125
# Batch no: 094, Loss on trainig: 2.6283, Accuracy: 0.2812
# Batch no: 095, Loss on trainig: 2.8693, Accuracy: 0.2344
# Batch no: 096, Loss on trainig: 2.7517, Accuracy: 0.2500
# Batch no: 097, Loss on trainig: 2.5662, Accuracy: 0.4062
# Batch no: 098, Loss on trainig: 2.5079, Accuracy: 0.3906
# Batch no: 099, Loss on trainig: 2.7005, Accuracy: 0.3125
# Batch no: 100, Loss on trainig: 2.3755, Accuracy: 0.4062
# Batch no: 101, Loss on trainig: 2.4638, Accuracy: 0.2969
# Batch no: 102, Loss on trainig: 2.7338, Accuracy: 0.1667
# 2
# Batch no: 000, Loss on trainig: 2.9352, Accuracy: 0.2031
# Batch no: 001, Loss on trainig: 2.4168, Accuracy: 0.3438
# Batch no: 002, Loss on trainig: 2.5895, Accuracy: 0.2188
# Batch no: 003, Loss on trainig: 2.6044, Accuracy: 0.2812
# Batch no: 004, Loss on trainig: 2.6038, Accuracy: 0.3125
# Batch no: 005, Loss on trainig: 2.6923, Accuracy: 0.2812
# Batch no: 006, Loss on trainig: 2.6670, Accuracy: 0.3438
# Batch no: 007, Loss on trainig: 2.8195, Accuracy: 0.2969
# Batch no: 008, Loss on trainig: 2.7524, Accuracy: 0.2656
# Batch no: 009, Loss on trainig: 2.4683, Accuracy: 0.3594
# Batch no: 010, Loss on trainig: 2.6992, Accuracy: 0.2500
# Batch no: 011, Loss on trainig: 2.3282, Accuracy: 0.4219
# Batch no: 012, Loss on trainig: 2.3855, Accuracy: 0.3750
# Batch no: 013, Loss on trainig: 2.4506, Accuracy: 0.3594
# Batch no: 014, Loss on trainig: 2.3395, Accuracy: 0.2812
# Batch no: 015, Loss on trainig: 2.5888, Accuracy: 0.3125
# Batch no: 016, Loss on trainig: 2.4641, Accuracy: 0.3750
# Batch no: 017, Loss on trainig: 2.4577, Accuracy: 0.3906
# Batch no: 018, Loss on trainig: 2.5505, Accuracy: 0.2969
# Batch no: 019, Loss on trainig: 2.7922, Accuracy: 0.3281
# Batch no: 020, Loss on trainig: 2.5000, Accuracy: 0.2812
# Batch no: 021, Loss on trainig: 2.4689, Accuracy: 0.3750
# Batch no: 022, Loss on trainig: 2.6189, Accuracy: 0.3125
# Batch no: 023, Loss on trainig: 2.3443, Accuracy: 0.3906
# Batch no: 024, Loss on trainig: 2.3560, Accuracy: 0.3281
# Batch no: 025, Loss on trainig: 2.5045, Accuracy: 0.3594
# Batch no: 026, Loss on trainig: 2.4709, Accuracy: 0.3750
# Batch no: 027, Loss on trainig: 2.5799, Accuracy: 0.3594
# Batch no: 028, Loss on trainig: 2.6329, Accuracy: 0.3281
# Batch no: 029, Loss on trainig: 2.5634, Accuracy: 0.3438
# Batch no: 030, Loss on trainig: 2.4250, Accuracy: 0.3125
# Batch no: 031, Loss on trainig: 2.6171, Accuracy: 0.3594
# Batch no: 032, Loss on trainig: 2.6918, Accuracy: 0.2500
# Batch no: 033, Loss on trainig: 2.3504, Accuracy: 0.3750
# Batch no: 034, Loss on trainig: 2.5789, Accuracy: 0.3281
# Batch no: 035, Loss on trainig: 2.7566, Accuracy: 0.2812
# Batch no: 036, Loss on trainig: 2.3349, Accuracy: 0.3594
# Batch no: 037, Loss on trainig: 2.5614, Accuracy: 0.2812
# Batch no: 038, Loss on trainig: 2.6113, Accuracy: 0.2656
# Batch no: 039, Loss on trainig: 2.1071, Accuracy: 0.4844
# Batch no: 040, Loss on trainig: 2.7537, Accuracy: 0.2969
# Batch no: 041, Loss on trainig: 2.7984, Accuracy: 0.2344
# Batch no: 042, Loss on trainig: 2.1331, Accuracy: 0.3750
# Batch no: 043, Loss on trainig: 2.1473, Accuracy: 0.4844
# Batch no: 044, Loss on trainig: 2.2975, Accuracy: 0.3906
# Batch no: 045, Loss on trainig: 2.4038, Accuracy: 0.3750
# Batch no: 046, Loss on trainig: 2.5936, Accuracy: 0.2969
# Batch no: 047, Loss on trainig: 2.3415, Accuracy: 0.4062
# Batch no: 048, Loss on trainig: 2.2798, Accuracy: 0.3906
# Batch no: 049, Loss on trainig: 2.2111, Accuracy: 0.3750
# Batch no: 050, Loss on trainig: 2.4304, Accuracy: 0.3438
# Batch no: 051, Loss on trainig: 2.4886, Accuracy: 0.3594
# Batch no: 052, Loss on trainig: 2.4172, Accuracy: 0.3438
# Batch no: 053, Loss on trainig: 2.5027, Accuracy: 0.3281
# Batch no: 054, Loss on trainig: 2.5634, Accuracy: 0.3438
# Batch no: 055, Loss on trainig: 2.3316, Accuracy: 0.3750
# Batch no: 056, Loss on trainig: 2.1687, Accuracy: 0.4219
# Batch no: 057, Loss on trainig: 2.5483, Accuracy: 0.3750
# Batch no: 058, Loss on trainig: 2.3927, Accuracy: 0.4062
# Batch no: 059, Loss on trainig: 2.8984, Accuracy: 0.2969
# Batch no: 060, Loss on trainig: 2.4204, Accuracy: 0.3594
# Batch no: 061, Loss on trainig: 2.3719, Accuracy: 0.3438
# Batch no: 062, Loss on trainig: 3.0099, Accuracy: 0.2656
# Batch no: 063, Loss on trainig: 2.1695, Accuracy: 0.4219
# Batch no: 064, Loss on trainig: 2.3127, Accuracy: 0.3281
# Batch no: 065, Loss on trainig: 2.3236, Accuracy: 0.4062
# Batch no: 066, Loss on trainig: 2.4761, Accuracy: 0.3125
# Batch no: 067, Loss on trainig: 2.0974, Accuracy: 0.4531
# Batch no: 068, Loss on trainig: 2.3296, Accuracy: 0.3438
# Batch no: 069, Loss on trainig: 2.5372, Accuracy: 0.3281
# Batch no: 070, Loss on trainig: 2.2209, Accuracy: 0.4688
# Batch no: 071, Loss on trainig: 2.6660, Accuracy: 0.4062
# Batch no: 072, Loss on trainig: 2.5670, Accuracy: 0.3438
# Batch no: 073, Loss on trainig: 2.2517, Accuracy: 0.3281
# Batch no: 074, Loss on trainig: 2.2521, Accuracy: 0.3750
# Batch no: 075, Loss on trainig: 2.1585, Accuracy: 0.4688
# Batch no: 076, Loss on trainig: 2.7115, Accuracy: 0.2812
# Batch no: 077, Loss on trainig: 2.1426, Accuracy: 0.4531
# Batch no: 078, Loss on trainig: 2.5602, Accuracy: 0.3594
# Batch no: 079, Loss on trainig: 2.4363, Accuracy: 0.3906
# Batch no: 080, Loss on trainig: 2.2374, Accuracy: 0.4062
# Batch no: 081, Loss on trainig: 2.3408, Accuracy: 0.3906
# Batch no: 082, Loss on trainig: 2.4200, Accuracy: 0.3750
# Batch no: 083, Loss on trainig: 2.2709, Accuracy: 0.4062
# Batch no: 084, Loss on trainig: 2.3308, Accuracy: 0.3906
# Batch no: 085, Loss on trainig: 2.6779, Accuracy: 0.3125
# Batch no: 086, Loss on trainig: 2.4275, Accuracy: 0.3906
# Batch no: 087, Loss on trainig: 2.6666, Accuracy: 0.2344
# Batch no: 088, Loss on trainig: 2.3242, Accuracy: 0.3750
# Batch no: 089, Loss on trainig: 2.2811, Accuracy: 0.3906
# Batch no: 090, Loss on trainig: 2.5554, Accuracy: 0.2969
# Batch no: 091, Loss on trainig: 2.2526, Accuracy: 0.4062
# Batch no: 092, Loss on trainig: 2.3481, Accuracy: 0.2969
# Batch no: 093, Loss on trainig: 1.9794, Accuracy: 0.4844
# Batch no: 094, Loss on trainig: 1.8236, Accuracy: 0.5000
# Batch no: 095, Loss on trainig: 2.5086, Accuracy: 0.3281
# Batch no: 096, Loss on trainig: 2.4487, Accuracy: 0.3906
# Batch no: 097, Loss on trainig: 2.3428, Accuracy: 0.3750
# Batch no: 098, Loss on trainig: 2.3852, Accuracy: 0.3906
# Batch no: 099, Loss on trainig: 2.3741, Accuracy: 0.4375
# Batch no: 100, Loss on trainig: 1.9329, Accuracy: 0.5312
# Batch no: 101, Loss on trainig: 2.2268, Accuracy: 0.4219
# Batch no: 102, Loss on trainig: 2.2937, Accuracy: 0.4167
# 3
# Batch no: 000, Loss on trainig: 2.2071, Accuracy: 0.4219
# Batch no: 001, Loss on trainig: 2.2139, Accuracy: 0.4219
# Batch no: 002, Loss on trainig: 2.2877, Accuracy: 0.4062
# Batch no: 003, Loss on trainig: 2.2813, Accuracy: 0.3594
# Batch no: 004, Loss on trainig: 2.5599, Accuracy: 0.3125
# Batch no: 005, Loss on trainig: 2.0257, Accuracy: 0.4219
# Batch no: 006, Loss on trainig: 2.2610, Accuracy: 0.3438
# Batch no: 007, Loss on trainig: 2.5082, Accuracy: 0.2969
# Batch no: 008, Loss on trainig: 2.0069, Accuracy: 0.3750
# Batch no: 009, Loss on trainig: 2.3726, Accuracy: 0.3750
# Batch no: 010, Loss on trainig: 2.0979, Accuracy: 0.4844
# Batch no: 011, Loss on trainig: 2.4259, Accuracy: 0.3750
# Batch no: 012, Loss on trainig: 2.3501, Accuracy: 0.3125
# Batch no: 013, Loss on trainig: 2.3447, Accuracy: 0.3906
# Batch no: 014, Loss on trainig: 2.2306, Accuracy: 0.3750
# Batch no: 015, Loss on trainig: 2.5416, Accuracy: 0.2969
# Batch no: 016, Loss on trainig: 1.7594, Accuracy: 0.5156
# Batch no: 017, Loss on trainig: 2.1429, Accuracy: 0.4062
# Batch no: 018, Loss on trainig: 2.0235, Accuracy: 0.4375
# Batch no: 019, Loss on trainig: 2.1402, Accuracy: 0.4375
# Batch no: 020, Loss on trainig: 2.3655, Accuracy: 0.4844
# Batch no: 021, Loss on trainig: 2.4772, Accuracy: 0.3750
# Batch no: 022, Loss on trainig: 2.4971, Accuracy: 0.3281
# Batch no: 023, Loss on trainig: 2.5924, Accuracy: 0.3594
# Batch no: 024, Loss on trainig: 2.3243, Accuracy: 0.3125
# Batch no: 025, Loss on trainig: 2.1015, Accuracy: 0.4062
# Batch no: 026, Loss on trainig: 2.4357, Accuracy: 0.3750
# Batch no: 027, Loss on trainig: 2.5122, Accuracy: 0.3438
# Batch no: 028, Loss on trainig: 2.1272, Accuracy: 0.4219
# Batch no: 029, Loss on trainig: 2.6751, Accuracy: 0.3438
# Batch no: 030, Loss on trainig: 2.0478, Accuracy: 0.4844
# Batch no: 031, Loss on trainig: 1.9303, Accuracy: 0.4062
# Batch no: 032, Loss on trainig: 2.3598, Accuracy: 0.4375
# Batch no: 033, Loss on trainig: 1.9171, Accuracy: 0.4844
# Batch no: 034, Loss on trainig: 2.1879, Accuracy: 0.4375
# Batch no: 035, Loss on trainig: 2.2251, Accuracy: 0.4375
# Batch no: 036, Loss on trainig: 2.1778, Accuracy: 0.4688
# Batch no: 037, Loss on trainig: 2.2672, Accuracy: 0.3750
# Batch no: 038, Loss on trainig: 1.9469, Accuracy: 0.4844
# Batch no: 039, Loss on trainig: 2.1977, Accuracy: 0.3750
# Batch no: 040, Loss on trainig: 2.0688, Accuracy: 0.3594
# Batch no: 041, Loss on trainig: 2.0779, Accuracy: 0.3594
# Batch no: 042, Loss on trainig: 2.1377, Accuracy: 0.4844
# Batch no: 043, Loss on trainig: 1.9549, Accuracy: 0.3750
# Batch no: 044, Loss on trainig: 2.1350, Accuracy: 0.4375
# Batch no: 045, Loss on trainig: 2.2470, Accuracy: 0.4531
# Batch no: 046, Loss on trainig: 2.2222, Accuracy: 0.3750
# Batch no: 047, Loss on trainig: 2.1628, Accuracy: 0.4062
# Batch no: 048, Loss on trainig: 2.7560, Accuracy: 0.3281
# Batch no: 049, Loss on trainig: 2.3424, Accuracy: 0.3906
# Batch no: 050, Loss on trainig: 2.1465, Accuracy: 0.3750
# Batch no: 051, Loss on trainig: 2.2815, Accuracy: 0.4062
# Batch no: 052, Loss on trainig: 2.0025, Accuracy: 0.4062
# Batch no: 053, Loss on trainig: 2.1986, Accuracy: 0.3750
# Batch no: 054, Loss on trainig: 2.3621, Accuracy: 0.4062
# Batch no: 055, Loss on trainig: 2.0761, Accuracy: 0.3594
# Batch no: 056, Loss on trainig: 2.1545, Accuracy: 0.5000
# Batch no: 057, Loss on trainig: 2.0532, Accuracy: 0.4219
# Batch no: 058, Loss on trainig: 2.1007, Accuracy: 0.3594
# Batch no: 059, Loss on trainig: 2.4010, Accuracy: 0.4219
# Batch no: 060, Loss on trainig: 2.0742, Accuracy: 0.4062
# Batch no: 061, Loss on trainig: 2.2511, Accuracy: 0.3594
# Batch no: 062, Loss on trainig: 2.3760, Accuracy: 0.4219
# Batch no: 063, Loss on trainig: 2.1504, Accuracy: 0.4062
# Batch no: 064, Loss on trainig: 2.1984, Accuracy: 0.4375
# Batch no: 065, Loss on trainig: 2.0929, Accuracy: 0.4531
# Batch no: 066, Loss on trainig: 2.3735, Accuracy: 0.3906
# Batch no: 067, Loss on trainig: 1.9994, Accuracy: 0.4688
# Batch no: 068, Loss on trainig: 2.3739, Accuracy: 0.4219
# Batch no: 069, Loss on trainig: 1.9907, Accuracy: 0.3594
# Batch no: 070, Loss on trainig: 2.2369, Accuracy: 0.3750
# Batch no: 071, Loss on trainig: 2.1546, Accuracy: 0.4531
# Batch no: 072, Loss on trainig: 2.0423, Accuracy: 0.4688
# Batch no: 073, Loss on trainig: 2.0706, Accuracy: 0.4688
# Batch no: 074, Loss on trainig: 1.7622, Accuracy: 0.5000
# Batch no: 075, Loss on trainig: 2.1934, Accuracy: 0.4062
# Batch no: 076, Loss on trainig: 2.1754, Accuracy: 0.3281
# Batch no: 077, Loss on trainig: 2.2827, Accuracy: 0.4219
# Batch no: 078, Loss on trainig: 1.8789, Accuracy: 0.5312
# Batch no: 079, Loss on trainig: 2.3081, Accuracy: 0.3125
# Batch no: 080, Loss on trainig: 2.1473, Accuracy: 0.3906
# Batch no: 081, Loss on trainig: 2.2418, Accuracy: 0.3750
# Batch no: 082, Loss on trainig: 2.0173, Accuracy: 0.4688
# Batch no: 083, Loss on trainig: 2.1396, Accuracy: 0.4531
# Batch no: 084, Loss on trainig: 2.4954, Accuracy: 0.3594
# Batch no: 085, Loss on trainig: 2.3445, Accuracy: 0.2969
# Batch no: 086, Loss on trainig: 2.4766, Accuracy: 0.4062
# Batch no: 087, Loss on trainig: 2.5875, Accuracy: 0.3594
# Batch no: 088, Loss on trainig: 1.8416, Accuracy: 0.4844
# Batch no: 089, Loss on trainig: 2.0593, Accuracy: 0.4062
# Batch no: 090, Loss on trainig: 1.6505, Accuracy: 0.5938
# Batch no: 091, Loss on trainig: 1.9935, Accuracy: 0.4688
# Batch no: 092, Loss on trainig: 2.3285, Accuracy: 0.3438
# Batch no: 093, Loss on trainig: 2.1989, Accuracy: 0.4219
# Batch no: 094, Loss on trainig: 2.2818, Accuracy: 0.3750
# Batch no: 095, Loss on trainig: 1.9011, Accuracy: 0.4375
# Batch no: 096, Loss on trainig: 2.0548, Accuracy: 0.4219
# Batch no: 097, Loss on trainig: 1.8988, Accuracy: 0.4062
# Batch no: 098, Loss on trainig: 2.5041, Accuracy: 0.2969
# Batch no: 099, Loss on trainig: 2.3459, Accuracy: 0.3594
# Batch no: 100, Loss on trainig: 2.2242, Accuracy: 0.4531
# Batch no: 101, Loss on trainig: 2.1838, Accuracy: 0.3438
# Batch no: 102, Loss on trainig: 1.8419, Accuracy: 0.5000
# 4
# Batch no: 000, Loss on trainig: 1.9292, Accuracy: 0.4531
# Batch no: 001, Loss on trainig: 2.0632, Accuracy: 0.4219
# Batch no: 002, Loss on trainig: 2.4665, Accuracy: 0.3125
# Batch no: 003, Loss on trainig: 1.5181, Accuracy: 0.5156
# Batch no: 004, Loss on trainig: 2.2071, Accuracy: 0.4844
# Batch no: 005, Loss on trainig: 2.2559, Accuracy: 0.4062
# Batch no: 006, Loss on trainig: 1.7878, Accuracy: 0.5156
# Batch no: 007, Loss on trainig: 2.3590, Accuracy: 0.4219
# Batch no: 008, Loss on trainig: 2.3256, Accuracy: 0.3594
# Batch no: 009, Loss on trainig: 1.8701, Accuracy: 0.5156
# Batch no: 010, Loss on trainig: 2.4128, Accuracy: 0.3125
# Batch no: 011, Loss on trainig: 2.4217, Accuracy: 0.3438
# Batch no: 012, Loss on trainig: 1.8893, Accuracy: 0.4219
# Batch no: 013, Loss on trainig: 1.9946, Accuracy: 0.4531
# Batch no: 014, Loss on trainig: 1.8131, Accuracy: 0.5156
# Batch no: 015, Loss on trainig: 1.9442, Accuracy: 0.4375
# Batch no: 016, Loss on trainig: 2.2316, Accuracy: 0.4531
# Batch no: 017, Loss on trainig: 2.1347, Accuracy: 0.4531
# Batch no: 018, Loss on trainig: 1.9615, Accuracy: 0.4219
# Batch no: 019, Loss on trainig: 2.3756, Accuracy: 0.3125
# Batch no: 020, Loss on trainig: 2.0626, Accuracy: 0.3438
# Batch no: 021, Loss on trainig: 2.0992, Accuracy: 0.3906
# Batch no: 022, Loss on trainig: 2.2429, Accuracy: 0.3594
# Batch no: 023, Loss on trainig: 1.9588, Accuracy: 0.4688
# Batch no: 024, Loss on trainig: 2.1339, Accuracy: 0.3750
# Batch no: 025, Loss on trainig: 2.0727, Accuracy: 0.4219
# Batch no: 026, Loss on trainig: 1.9990, Accuracy: 0.4844
# Batch no: 027, Loss on trainig: 2.6663, Accuracy: 0.3438
# Batch no: 028, Loss on trainig: 2.0408, Accuracy: 0.4062
# Batch no: 029, Loss on trainig: 2.1136, Accuracy: 0.3438
# Batch no: 030, Loss on trainig: 2.1940, Accuracy: 0.4062
# Batch no: 031, Loss on trainig: 2.1451, Accuracy: 0.4062
# Batch no: 032, Loss on trainig: 2.1380, Accuracy: 0.3438
# Batch no: 033, Loss on trainig: 1.9707, Accuracy: 0.4219
# Batch no: 034, Loss on trainig: 2.0718, Accuracy: 0.4688
# Batch no: 035, Loss on trainig: 1.9524, Accuracy: 0.4531
# Batch no: 036, Loss on trainig: 1.8553, Accuracy: 0.4531
# Batch no: 037, Loss on trainig: 2.0912, Accuracy: 0.4688
# Batch no: 038, Loss on trainig: 2.0409, Accuracy: 0.4375
# Batch no: 039, Loss on trainig: 2.0941, Accuracy: 0.4844
# Batch no: 040, Loss on trainig: 2.3854, Accuracy: 0.2969
# Batch no: 041, Loss on trainig: 2.1034, Accuracy: 0.4531
# Batch no: 042, Loss on trainig: 1.7969, Accuracy: 0.5156
# Batch no: 043, Loss on trainig: 1.9768, Accuracy: 0.4531
# Batch no: 044, Loss on trainig: 2.0949, Accuracy: 0.4219
# Batch no: 045, Loss on trainig: 1.9165, Accuracy: 0.4375
# Batch no: 046, Loss on trainig: 2.2702, Accuracy: 0.4062
# Batch no: 047, Loss on trainig: 2.4056, Accuracy: 0.4531
# Batch no: 048, Loss on trainig: 2.2795, Accuracy: 0.4062
# Batch no: 049, Loss on trainig: 2.0875, Accuracy: 0.3438
# Batch no: 050, Loss on trainig: 1.8682, Accuracy: 0.4844
# Batch no: 051, Loss on trainig: 1.9630, Accuracy: 0.4844
# Batch no: 052, Loss on trainig: 2.4717, Accuracy: 0.3125
# Batch no: 053, Loss on trainig: 1.8966, Accuracy: 0.4375
# Batch no: 054, Loss on trainig: 2.1795, Accuracy: 0.4688
# Batch no: 055, Loss on trainig: 2.4513, Accuracy: 0.3281
# Batch no: 056, Loss on trainig: 2.1599, Accuracy: 0.3750
# Batch no: 057, Loss on trainig: 2.0445, Accuracy: 0.5312
# Batch no: 058, Loss on trainig: 2.0884, Accuracy: 0.4688
# Batch no: 059, Loss on trainig: 2.0082, Accuracy: 0.4844
# Batch no: 060, Loss on trainig: 2.0949, Accuracy: 0.5000
# Batch no: 061, Loss on trainig: 2.3592, Accuracy: 0.3594
# Batch no: 062, Loss on trainig: 2.0444, Accuracy: 0.4844
# Batch no: 063, Loss on trainig: 2.0378, Accuracy: 0.4531
# Batch no: 064, Loss on trainig: 2.0560, Accuracy: 0.3906
# Batch no: 065, Loss on trainig: 1.5111, Accuracy: 0.5938
# Batch no: 066, Loss on trainig: 1.7699, Accuracy: 0.5000
# Batch no: 067, Loss on trainig: 2.2483, Accuracy: 0.3750
# Batch no: 068, Loss on trainig: 2.0149, Accuracy: 0.5312
# Batch no: 069, Loss on trainig: 1.9358, Accuracy: 0.4219
# Batch no: 070, Loss on trainig: 2.4638, Accuracy: 0.4062
# Batch no: 071, Loss on trainig: 2.2412, Accuracy: 0.4062
# Batch no: 072, Loss on trainig: 2.4650, Accuracy: 0.3906
# Batch no: 073, Loss on trainig: 2.3283, Accuracy: 0.3281
# Batch no: 074, Loss on trainig: 1.8477, Accuracy: 0.5156
# Batch no: 075, Loss on trainig: 2.0010, Accuracy: 0.3750
# Batch no: 076, Loss on trainig: 2.1415, Accuracy: 0.3125
# Batch no: 077, Loss on trainig: 2.0121, Accuracy: 0.4844
# Batch no: 078, Loss on trainig: 2.2934, Accuracy: 0.4531
# Batch no: 079, Loss on trainig: 2.1425, Accuracy: 0.4531
# Batch no: 080, Loss on trainig: 2.1196, Accuracy: 0.4062
# Batch no: 081, Loss on trainig: 2.3527, Accuracy: 0.3594
# Batch no: 082, Loss on trainig: 1.9893, Accuracy: 0.4062
# Batch no: 083, Loss on trainig: 2.3273, Accuracy: 0.4688
# Batch no: 084, Loss on trainig: 2.2850, Accuracy: 0.3594
# Batch no: 085, Loss on trainig: 2.1032, Accuracy: 0.3750
# Batch no: 086, Loss on trainig: 1.8269, Accuracy: 0.4844
# Batch no: 087, Loss on trainig: 1.9771, Accuracy: 0.4375
# Batch no: 088, Loss on trainig: 2.0896, Accuracy: 0.4844
# Batch no: 089, Loss on trainig: 2.0663, Accuracy: 0.4688
# Batch no: 090, Loss on trainig: 2.1087, Accuracy: 0.4219
# Batch no: 091, Loss on trainig: 1.8097, Accuracy: 0.5000
# Batch no: 092, Loss on trainig: 1.8734, Accuracy: 0.5000
# Batch no: 093, Loss on trainig: 2.1032, Accuracy: 0.3906
# Batch no: 094, Loss on trainig: 1.7311, Accuracy: 0.5625
# Batch no: 095, Loss on trainig: 1.8073, Accuracy: 0.5312
# Batch no: 096, Loss on trainig: 2.2612, Accuracy: 0.3594
# Batch no: 097, Loss on trainig: 2.0156, Accuracy: 0.4688
# Batch no: 098, Loss on trainig: 2.0443, Accuracy: 0.4062
# Batch no: 099, Loss on trainig: 1.8629, Accuracy: 0.4844
# Batch no: 100, Loss on trainig: 1.8149, Accuracy: 0.5000
# Batch no: 101, Loss on trainig: 2.1126, Accuracy: 0.3750
# Batch no: 102, Loss on trainig: 1.5330, Accuracy: 0.6250
# 5
# Batch no: 000, Loss on trainig: 1.6161, Accuracy: 0.5938
# Batch no: 001, Loss on trainig: 1.4508, Accuracy: 0.6406
# Batch no: 002, Loss on trainig: 1.6035, Accuracy: 0.5312
# Batch no: 003, Loss on trainig: 1.9500, Accuracy: 0.4844
# Batch no: 004, Loss on trainig: 1.7506, Accuracy: 0.5469
# Batch no: 005, Loss on trainig: 1.9564, Accuracy: 0.4375
# Batch no: 006, Loss on trainig: 1.8091, Accuracy: 0.4844
# Batch no: 007, Loss on trainig: 2.4144, Accuracy: 0.3750
# Batch no: 008, Loss on trainig: 2.3745, Accuracy: 0.3594
# Batch no: 009, Loss on trainig: 1.9083, Accuracy: 0.4688
# Batch no: 010, Loss on trainig: 1.9024, Accuracy: 0.4844
# Batch no: 011, Loss on trainig: 2.0408, Accuracy: 0.3750
# Batch no: 012, Loss on trainig: 2.0315, Accuracy: 0.4219
# Batch no: 013, Loss on trainig: 1.9562, Accuracy: 0.4219
# Batch no: 014, Loss on trainig: 1.7822, Accuracy: 0.5469
# Batch no: 015, Loss on trainig: 2.0003, Accuracy: 0.4531
# Batch no: 016, Loss on trainig: 2.4568, Accuracy: 0.3594
# Batch no: 017, Loss on trainig: 2.1946, Accuracy: 0.4375
# Batch no: 018, Loss on trainig: 1.6935, Accuracy: 0.5625
# Batch no: 019, Loss on trainig: 1.7843, Accuracy: 0.5156
# Batch no: 020, Loss on trainig: 1.9558, Accuracy: 0.5312
# Batch no: 021, Loss on trainig: 1.9855, Accuracy: 0.4219
# Batch no: 022, Loss on trainig: 1.9571, Accuracy: 0.5156
# Batch no: 023, Loss on trainig: 1.9465, Accuracy: 0.4531
# Batch no: 024, Loss on trainig: 1.9179, Accuracy: 0.5156
# Batch no: 025, Loss on trainig: 2.2625, Accuracy: 0.3906
# Batch no: 026, Loss on trainig: 2.1998, Accuracy: 0.5000
# Batch no: 027, Loss on trainig: 1.7313, Accuracy: 0.5000
# Batch no: 028, Loss on trainig: 1.9992, Accuracy: 0.3906
# Batch no: 029, Loss on trainig: 2.0812, Accuracy: 0.4375
# Batch no: 030, Loss on trainig: 1.9197, Accuracy: 0.4688
# Batch no: 031, Loss on trainig: 1.6924, Accuracy: 0.5625
# Batch no: 032, Loss on trainig: 1.9021, Accuracy: 0.4688
# Batch no: 033, Loss on trainig: 2.0908, Accuracy: 0.4688
# Batch no: 034, Loss on trainig: 2.1756, Accuracy: 0.4219
# Batch no: 035, Loss on trainig: 1.9870, Accuracy: 0.4688
# Batch no: 036, Loss on trainig: 1.7282, Accuracy: 0.5156
# Batch no: 037, Loss on trainig: 1.7745, Accuracy: 0.5156
# Batch no: 038, Loss on trainig: 1.9394, Accuracy: 0.5000
# Batch no: 039, Loss on trainig: 1.5930, Accuracy: 0.5781
# Batch no: 040, Loss on trainig: 2.0676, Accuracy: 0.4219
# Batch no: 041, Loss on trainig: 2.0293, Accuracy: 0.4062
# Batch no: 042, Loss on trainig: 2.1275, Accuracy: 0.4219
# Batch no: 043, Loss on trainig: 2.1871, Accuracy: 0.4062
# Batch no: 044, Loss on trainig: 2.2251, Accuracy: 0.4375
# Batch no: 045, Loss on trainig: 1.9107, Accuracy: 0.4688
# Batch no: 046, Loss on trainig: 2.2706, Accuracy: 0.4219
# Batch no: 047, Loss on trainig: 2.0052, Accuracy: 0.5000
# Batch no: 048, Loss on trainig: 2.0124, Accuracy: 0.4531
# Batch no: 049, Loss on trainig: 2.2071, Accuracy: 0.4531
# Batch no: 050, Loss on trainig: 1.9708, Accuracy: 0.4844
# Batch no: 051, Loss on trainig: 1.8244, Accuracy: 0.4688
# Batch no: 052, Loss on trainig: 1.9076, Accuracy: 0.4531
# Batch no: 053, Loss on trainig: 1.6674, Accuracy: 0.5000
# Batch no: 054, Loss on trainig: 1.8255, Accuracy: 0.5156
# Batch no: 055, Loss on trainig: 1.9667, Accuracy: 0.4375
# Batch no: 056, Loss on trainig: 1.7630, Accuracy: 0.5781
# Batch no: 057, Loss on trainig: 1.8941, Accuracy: 0.5312
# Batch no: 058, Loss on trainig: 2.1802, Accuracy: 0.3438
# Batch no: 059, Loss on trainig: 1.7568, Accuracy: 0.5625
# Batch no: 060, Loss on trainig: 1.7956, Accuracy: 0.5469
# Batch no: 061, Loss on trainig: 2.0506, Accuracy: 0.3750
# Batch no: 062, Loss on trainig: 2.1036, Accuracy: 0.4531
# Batch no: 063, Loss on trainig: 2.2231, Accuracy: 0.3594
# Batch no: 064, Loss on trainig: 2.4256, Accuracy: 0.4688
# Batch no: 065, Loss on trainig: 1.6852, Accuracy: 0.5000
# Batch no: 066, Loss on trainig: 2.0571, Accuracy: 0.4844
# Batch no: 067, Loss on trainig: 1.6605, Accuracy: 0.5000
# Batch no: 068, Loss on trainig: 1.8586, Accuracy: 0.4688
# Batch no: 069, Loss on trainig: 2.3519, Accuracy: 0.4219
# Batch no: 070, Loss on trainig: 2.0731, Accuracy: 0.4219
# Batch no: 071, Loss on trainig: 2.1283, Accuracy: 0.4062
# Batch no: 072, Loss on trainig: 2.0185, Accuracy: 0.5000
# Batch no: 073, Loss on trainig: 2.0214, Accuracy: 0.4531
# Batch no: 074, Loss on trainig: 2.0136, Accuracy: 0.4688
# Batch no: 075, Loss on trainig: 1.8211, Accuracy: 0.5938
# Batch no: 076, Loss on trainig: 2.0219, Accuracy: 0.4062
# Batch no: 077, Loss on trainig: 1.9358, Accuracy: 0.4375
# Batch no: 078, Loss on trainig: 2.0073, Accuracy: 0.4531
# Batch no: 079, Loss on trainig: 1.8871, Accuracy: 0.5000
# Batch no: 080, Loss on trainig: 1.8839, Accuracy: 0.5156
# Batch no: 081, Loss on trainig: 1.5721, Accuracy: 0.5312
# Batch no: 082, Loss on trainig: 1.7247, Accuracy: 0.4531
# Batch no: 083, Loss on trainig: 1.6115, Accuracy: 0.5469
# Batch no: 084, Loss on trainig: 1.7476, Accuracy: 0.5000
# Batch no: 085, Loss on trainig: 2.1835, Accuracy: 0.4375
# Batch no: 086, Loss on trainig: 1.9917, Accuracy: 0.4219
# Batch no: 087, Loss on trainig: 2.6046, Accuracy: 0.3594
# Batch no: 088, Loss on trainig: 2.0198, Accuracy: 0.4219
# Batch no: 089, Loss on trainig: 1.6328, Accuracy: 0.5312
# Batch no: 090, Loss on trainig: 1.9946, Accuracy: 0.5156
# Batch no: 091, Loss on trainig: 1.8198, Accuracy: 0.5000
# Batch no: 092, Loss on trainig: 2.1940, Accuracy: 0.4688
# Batch no: 093, Loss on trainig: 2.4381, Accuracy: 0.3438
# Batch no: 094, Loss on trainig: 1.8555, Accuracy: 0.5000
# Batch no: 095, Loss on trainig: 1.9078, Accuracy: 0.4688
# Batch no: 096, Loss on trainig: 1.8439, Accuracy: 0.5000
# Batch no: 097, Loss on trainig: 1.8344, Accuracy: 0.5156
# Batch no: 098, Loss on trainig: 2.3931, Accuracy: 0.3906
# Batch no: 099, Loss on trainig: 1.7202, Accuracy: 0.5469
# Batch no: 100, Loss on trainig: 2.1786, Accuracy: 0.4375
# Batch no: 101, Loss on trainig: 1.8766, Accuracy: 0.5781
# Batch no: 102, Loss on trainig: 1.9306, Accuracy: 0.5417
# 6
# Batch no: 000, Loss on trainig: 1.6160, Accuracy: 0.5625
# Batch no: 001, Loss on trainig: 1.6060, Accuracy: 0.5156
# Batch no: 002, Loss on trainig: 1.9569, Accuracy: 0.4844
# Batch no: 003, Loss on trainig: 2.2111, Accuracy: 0.3594
# Batch no: 004, Loss on trainig: 2.1557, Accuracy: 0.4375
# Batch no: 005, Loss on trainig: 1.9201, Accuracy: 0.5469
# Batch no: 006, Loss on trainig: 2.0641, Accuracy: 0.4688
# Batch no: 007, Loss on trainig: 2.3693, Accuracy: 0.4062
# Batch no: 008, Loss on trainig: 2.0067, Accuracy: 0.5000
# Batch no: 009, Loss on trainig: 2.0056, Accuracy: 0.4688
# Batch no: 010, Loss on trainig: 1.5969, Accuracy: 0.5938
# Batch no: 011, Loss on trainig: 2.0471, Accuracy: 0.4375
# Batch no: 012, Loss on trainig: 2.0771, Accuracy: 0.4219
# Batch no: 013, Loss on trainig: 2.0428, Accuracy: 0.4688
# Batch no: 014, Loss on trainig: 2.1754, Accuracy: 0.4219
# Batch no: 015, Loss on trainig: 2.1742, Accuracy: 0.4219
# Batch no: 016, Loss on trainig: 2.0167, Accuracy: 0.4219
# Batch no: 017, Loss on trainig: 1.5473, Accuracy: 0.5156
# Batch no: 018, Loss on trainig: 1.7645, Accuracy: 0.4688
# Batch no: 019, Loss on trainig: 1.6545, Accuracy: 0.5469
# Batch no: 020, Loss on trainig: 1.9467, Accuracy: 0.4531
# Batch no: 021, Loss on trainig: 1.7844, Accuracy: 0.5000
# Batch no: 022, Loss on trainig: 2.1586, Accuracy: 0.4375
# Batch no: 023, Loss on trainig: 1.6236, Accuracy: 0.4844
# Batch no: 024, Loss on trainig: 1.7301, Accuracy: 0.4688
# Batch no: 025, Loss on trainig: 1.9524, Accuracy: 0.3906
# Batch no: 026, Loss on trainig: 2.1555, Accuracy: 0.4375
# Batch no: 027, Loss on trainig: 1.3733, Accuracy: 0.5469
# Batch no: 028, Loss on trainig: 1.8719, Accuracy: 0.4219
# Batch no: 029, Loss on trainig: 1.7071, Accuracy: 0.5000
# Batch no: 030, Loss on trainig: 1.6442, Accuracy: 0.5000
# Batch no: 031, Loss on trainig: 1.7068, Accuracy: 0.4375
# Batch no: 032, Loss on trainig: 1.5763, Accuracy: 0.5781
# Batch no: 033, Loss on trainig: 1.9231, Accuracy: 0.5469
# Batch no: 034, Loss on trainig: 2.1029, Accuracy: 0.3750
# Batch no: 035, Loss on trainig: 1.8342, Accuracy: 0.5781
# Batch no: 036, Loss on trainig: 1.8571, Accuracy: 0.5000
# Batch no: 037, Loss on trainig: 2.0051, Accuracy: 0.4375
# Batch no: 038, Loss on trainig: 2.1836, Accuracy: 0.4375
# Batch no: 039, Loss on trainig: 2.0262, Accuracy: 0.3594
# Batch no: 040, Loss on trainig: 1.5900, Accuracy: 0.5938
# Batch no: 041, Loss on trainig: 1.9988, Accuracy: 0.4844
# Batch no: 042, Loss on trainig: 1.8369, Accuracy: 0.3906
# Batch no: 043, Loss on trainig: 1.7534, Accuracy: 0.5000
# Batch no: 044, Loss on trainig: 1.9953, Accuracy: 0.4375
# Batch no: 045, Loss on trainig: 1.7235, Accuracy: 0.5781
# Batch no: 046, Loss on trainig: 2.0271, Accuracy: 0.4375
# Batch no: 047, Loss on trainig: 2.1974, Accuracy: 0.4688
# Batch no: 048, Loss on trainig: 1.8757, Accuracy: 0.5625
# Batch no: 049, Loss on trainig: 1.7990, Accuracy: 0.5156
# Batch no: 050, Loss on trainig: 1.9216, Accuracy: 0.4844
# Batch no: 051, Loss on trainig: 1.9614, Accuracy: 0.5156
# Batch no: 052, Loss on trainig: 1.5704, Accuracy: 0.6250
# Batch no: 053, Loss on trainig: 1.7951, Accuracy: 0.5312
# Batch no: 054, Loss on trainig: 2.0989, Accuracy: 0.4688
# Batch no: 055, Loss on trainig: 2.0696, Accuracy: 0.4375
# Batch no: 056, Loss on trainig: 1.7496, Accuracy: 0.4688
# Batch no: 057, Loss on trainig: 1.9852, Accuracy: 0.4375
# Batch no: 058, Loss on trainig: 2.0526, Accuracy: 0.4219
# Batch no: 059, Loss on trainig: 1.9641, Accuracy: 0.4688
# Batch no: 060, Loss on trainig: 1.7853, Accuracy: 0.4688
# Batch no: 061, Loss on trainig: 2.0604, Accuracy: 0.5312
# Batch no: 062, Loss on trainig: 1.8437, Accuracy: 0.5625
# Batch no: 063, Loss on trainig: 1.6492, Accuracy: 0.5156
# Batch no: 064, Loss on trainig: 1.5857, Accuracy: 0.5781
# Batch no: 065, Loss on trainig: 1.8371, Accuracy: 0.4531
# Batch no: 066, Loss on trainig: 2.3054, Accuracy: 0.3750
# Batch no: 067, Loss on trainig: 2.1092, Accuracy: 0.4688
# Batch no: 068, Loss on trainig: 2.5897, Accuracy: 0.3906
# Batch no: 069, Loss on trainig: 2.2668, Accuracy: 0.4375
# Batch no: 070, Loss on trainig: 1.9133, Accuracy: 0.4219
# Batch no: 071, Loss on trainig: 1.8025, Accuracy: 0.5938
# Batch no: 072, Loss on trainig: 1.9683, Accuracy: 0.5000
# Batch no: 073, Loss on trainig: 2.3880, Accuracy: 0.4062
# Batch no: 074, Loss on trainig: 1.9549, Accuracy: 0.4531
# Batch no: 075, Loss on trainig: 2.0055, Accuracy: 0.4062
# Batch no: 076, Loss on trainig: 1.9617, Accuracy: 0.5156
# Batch no: 077, Loss on trainig: 2.0319, Accuracy: 0.3906
# Batch no: 078, Loss on trainig: 1.7569, Accuracy: 0.4844
# Batch no: 079, Loss on trainig: 2.1652, Accuracy: 0.3750
# Batch no: 080, Loss on trainig: 1.6862, Accuracy: 0.5625
# Batch no: 081, Loss on trainig: 1.7433, Accuracy: 0.4688
# Batch no: 082, Loss on trainig: 1.5942, Accuracy: 0.5625
# Batch no: 083, Loss on trainig: 2.0376, Accuracy: 0.3594
# Batch no: 084, Loss on trainig: 1.8738, Accuracy: 0.4844
# Batch no: 085, Loss on trainig: 1.5031, Accuracy: 0.6406
# Batch no: 086, Loss on trainig: 2.1825, Accuracy: 0.4062
# Batch no: 087, Loss on trainig: 2.3382, Accuracy: 0.4062
# Batch no: 088, Loss on trainig: 1.9455, Accuracy: 0.4375
# Batch no: 089, Loss on trainig: 1.8097, Accuracy: 0.4688
# Batch no: 090, Loss on trainig: 1.5923, Accuracy: 0.5156
# Batch no: 091, Loss on trainig: 1.8524, Accuracy: 0.4844
# Batch no: 092, Loss on trainig: 1.9504, Accuracy: 0.4219
# Batch no: 093, Loss on trainig: 2.0966, Accuracy: 0.4219
# Batch no: 094, Loss on trainig: 1.9325, Accuracy: 0.3594
# Batch no: 095, Loss on trainig: 1.6379, Accuracy: 0.5938
# Batch no: 096, Loss on trainig: 1.8282, Accuracy: 0.4844
# Batch no: 097, Loss on trainig: 2.0405, Accuracy: 0.4688
# Batch no: 098, Loss on trainig: 1.5286, Accuracy: 0.5938
# Batch no: 099, Loss on trainig: 1.6421, Accuracy: 0.5312
# Batch no: 100, Loss on trainig: 2.4029, Accuracy: 0.4844
# Batch no: 101, Loss on trainig: 2.1937, Accuracy: 0.4375
# Batch no: 102, Loss on trainig: 1.5637, Accuracy: 0.5417
# 7
# Batch no: 000, Loss on trainig: 1.7393, Accuracy: 0.4688
# Batch no: 001, Loss on trainig: 1.9830, Accuracy: 0.4219
# Batch no: 002, Loss on trainig: 1.6594, Accuracy: 0.5469
# Batch no: 003, Loss on trainig: 2.1257, Accuracy: 0.4219
# Batch no: 004, Loss on trainig: 1.7880, Accuracy: 0.4844
# Batch no: 005, Loss on trainig: 1.9503, Accuracy: 0.4375
# Batch no: 006, Loss on trainig: 1.9852, Accuracy: 0.4531
# Batch no: 007, Loss on trainig: 1.3833, Accuracy: 0.6250
# Batch no: 008, Loss on trainig: 1.5764, Accuracy: 0.5156
# Batch no: 009, Loss on trainig: 1.8584, Accuracy: 0.4531
# Batch no: 010, Loss on trainig: 1.5966, Accuracy: 0.5156
# Batch no: 011, Loss on trainig: 1.9720, Accuracy: 0.4219
# Batch no: 012, Loss on trainig: 1.8216, Accuracy: 0.4531
# Batch no: 013, Loss on trainig: 1.7008, Accuracy: 0.5000
# Batch no: 014, Loss on trainig: 1.9499, Accuracy: 0.4531
# Batch no: 015, Loss on trainig: 1.9039, Accuracy: 0.4531
# Batch no: 016, Loss on trainig: 2.0135, Accuracy: 0.4531
# Batch no: 017, Loss on trainig: 1.9842, Accuracy: 0.4062
# Batch no: 018, Loss on trainig: 1.7356, Accuracy: 0.5469
# Batch no: 019, Loss on trainig: 1.8891, Accuracy: 0.4688
# Batch no: 020, Loss on trainig: 1.8376, Accuracy: 0.4375
# Batch no: 021, Loss on trainig: 1.8708, Accuracy: 0.4688
# Batch no: 022, Loss on trainig: 1.7748, Accuracy: 0.5312
# Batch no: 023, Loss on trainig: 2.0100, Accuracy: 0.4375
# Batch no: 024, Loss on trainig: 1.7303, Accuracy: 0.4688
# Batch no: 025, Loss on trainig: 1.8633, Accuracy: 0.5000
# Batch no: 026, Loss on trainig: 1.5281, Accuracy: 0.5781
# Batch no: 027, Loss on trainig: 1.8571, Accuracy: 0.4375
# Batch no: 028, Loss on trainig: 1.7962, Accuracy: 0.5312
# Batch no: 029, Loss on trainig: 1.7998, Accuracy: 0.5156
# Batch no: 030, Loss on trainig: 1.6719, Accuracy: 0.5156
# Batch no: 031, Loss on trainig: 1.8744, Accuracy: 0.4375
# Batch no: 032, Loss on trainig: 1.6494, Accuracy: 0.5000
# Batch no: 033, Loss on trainig: 1.9197, Accuracy: 0.4219
# Batch no: 034, Loss on trainig: 1.7198, Accuracy: 0.5625
# Batch no: 035, Loss on trainig: 2.1694, Accuracy: 0.4062
# Batch no: 036, Loss on trainig: 2.0052, Accuracy: 0.5000
# Batch no: 037, Loss on trainig: 2.0205, Accuracy: 0.5312
# Batch no: 038, Loss on trainig: 1.5990, Accuracy: 0.5000
# Batch no: 039, Loss on trainig: 1.8272, Accuracy: 0.5000
# Batch no: 040, Loss on trainig: 1.7832, Accuracy: 0.4219
# Batch no: 041, Loss on trainig: 1.7832, Accuracy: 0.4844
# Batch no: 042, Loss on trainig: 1.5779, Accuracy: 0.5938
# Batch no: 043, Loss on trainig: 2.0615, Accuracy: 0.5000
# Batch no: 044, Loss on trainig: 1.8851, Accuracy: 0.5000
# Batch no: 045, Loss on trainig: 1.9830, Accuracy: 0.4531
# Batch no: 046, Loss on trainig: 2.2760, Accuracy: 0.4375
# Batch no: 047, Loss on trainig: 1.7727, Accuracy: 0.5312
# Batch no: 048, Loss on trainig: 1.9522, Accuracy: 0.4531
# Batch no: 049, Loss on trainig: 1.7125, Accuracy: 0.4688
# Batch no: 050, Loss on trainig: 1.4463, Accuracy: 0.6250
# Batch no: 051, Loss on trainig: 2.2814, Accuracy: 0.4219
# Batch no: 052, Loss on trainig: 1.8819, Accuracy: 0.5000
# Batch no: 053, Loss on trainig: 1.9823, Accuracy: 0.4531
# Batch no: 054, Loss on trainig: 1.9099, Accuracy: 0.5469
# Batch no: 055, Loss on trainig: 2.3043, Accuracy: 0.3594
# Batch no: 056, Loss on trainig: 1.8748, Accuracy: 0.4844
# Batch no: 057, Loss on trainig: 1.8387, Accuracy: 0.5469
# Batch no: 058, Loss on trainig: 1.9598, Accuracy: 0.4219
# Batch no: 059, Loss on trainig: 1.7717, Accuracy: 0.4844
# Batch no: 060, Loss on trainig: 1.9057, Accuracy: 0.4844
# Batch no: 061, Loss on trainig: 1.7188, Accuracy: 0.4844
# Batch no: 062, Loss on trainig: 1.9010, Accuracy: 0.5625
# Batch no: 063, Loss on trainig: 1.9892, Accuracy: 0.5000
# Batch no: 064, Loss on trainig: 1.9379, Accuracy: 0.4688
# Batch no: 065, Loss on trainig: 1.5976, Accuracy: 0.5625
# Batch no: 066, Loss on trainig: 2.0703, Accuracy: 0.4375
# Batch no: 067, Loss on trainig: 2.2857, Accuracy: 0.4219
# Batch no: 068, Loss on trainig: 1.7947, Accuracy: 0.5156
# Batch no: 069, Loss on trainig: 1.5740, Accuracy: 0.5312
# Batch no: 070, Loss on trainig: 1.8408, Accuracy: 0.4688
# Batch no: 071, Loss on trainig: 1.8901, Accuracy: 0.5156
# Batch no: 072, Loss on trainig: 1.9067, Accuracy: 0.4375
# Batch no: 073, Loss on trainig: 1.6446, Accuracy: 0.6406
# Batch no: 074, Loss on trainig: 1.7782, Accuracy: 0.4531
# Batch no: 075, Loss on trainig: 1.9261, Accuracy: 0.4844
# Batch no: 076, Loss on trainig: 1.7773, Accuracy: 0.5625
# Batch no: 077, Loss on trainig: 1.9690, Accuracy: 0.4375
# Batch no: 078, Loss on trainig: 1.9568, Accuracy: 0.5000
# Batch no: 079, Loss on trainig: 1.6590, Accuracy: 0.4531
# Batch no: 080, Loss on trainig: 2.1725, Accuracy: 0.5000
# Batch no: 081, Loss on trainig: 1.5349, Accuracy: 0.5469
# Batch no: 082, Loss on trainig: 1.8691, Accuracy: 0.5156
# Batch no: 083, Loss on trainig: 1.9878, Accuracy: 0.4375
# Batch no: 084, Loss on trainig: 1.8005, Accuracy: 0.4844
# Batch no: 085, Loss on trainig: 2.1350, Accuracy: 0.3750
# Batch no: 086, Loss on trainig: 1.4602, Accuracy: 0.6406
# Batch no: 087, Loss on trainig: 1.7021, Accuracy: 0.5156
# Batch no: 088, Loss on trainig: 2.1101, Accuracy: 0.4688
# Batch no: 089, Loss on trainig: 1.6119, Accuracy: 0.5312
# Batch no: 090, Loss on trainig: 2.0387, Accuracy: 0.4688
# Batch no: 091, Loss on trainig: 1.5218, Accuracy: 0.5469
# Batch no: 092, Loss on trainig: 1.8496, Accuracy: 0.4844
# Batch no: 093, Loss on trainig: 2.2293, Accuracy: 0.3750
# Batch no: 094, Loss on trainig: 2.3187, Accuracy: 0.4844
# Batch no: 095, Loss on trainig: 2.1406, Accuracy: 0.4219
# Batch no: 096, Loss on trainig: 1.8302, Accuracy: 0.5625
# Batch no: 097, Loss on trainig: 1.7428, Accuracy: 0.5000
# Batch no: 098, Loss on trainig: 1.9173, Accuracy: 0.4844
# Batch no: 099, Loss on trainig: 1.9203, Accuracy: 0.5469
# Batch no: 100, Loss on trainig: 1.7236, Accuracy: 0.5000
# Batch no: 101, Loss on trainig: 2.0343, Accuracy: 0.5000
# Batch no: 102, Loss on trainig: 1.2582, Accuracy: 0.6667
# 8
# Batch no: 000, Loss on trainig: 2.2678, Accuracy: 0.4062
# Batch no: 001, Loss on trainig: 1.8712, Accuracy: 0.4531
# Batch no: 002, Loss on trainig: 1.6906, Accuracy: 0.4844
# Batch no: 003, Loss on trainig: 1.8115, Accuracy: 0.5781
# Batch no: 004, Loss on trainig: 1.4744, Accuracy: 0.5625
# Batch no: 005, Loss on trainig: 1.8423, Accuracy: 0.5000
# Batch no: 006, Loss on trainig: 1.8525, Accuracy: 0.5469
# Batch no: 007, Loss on trainig: 1.9925, Accuracy: 0.4531
# Batch no: 008, Loss on trainig: 1.6486, Accuracy: 0.5781
# Batch no: 009, Loss on trainig: 1.9559, Accuracy: 0.5156
# Batch no: 010, Loss on trainig: 1.8634, Accuracy: 0.4531
# Batch no: 011, Loss on trainig: 1.5182, Accuracy: 0.6250
# Batch no: 012, Loss on trainig: 1.7164, Accuracy: 0.5000
# Batch no: 013, Loss on trainig: 1.4731, Accuracy: 0.5312
# Batch no: 014, Loss on trainig: 1.4334, Accuracy: 0.5625
# Batch no: 015, Loss on trainig: 1.6203, Accuracy: 0.4844
# Batch no: 016, Loss on trainig: 1.5563, Accuracy: 0.5156
# ...
# Batch no: 029, Loss on trainig: 1.3074, Accuracy: 0.6250
# Batch no: 030, Loss on trainig: 1.4913, Accuracy: 0.5938
# Batch no: 031, Loss on trainig: 1.8325, Accuracy: 0.4688
# Batch no: 032, Loss on trainig: 1.1716, Accuracy: 0.6406
# Batch no: 033, Loss on trainig: 1.4836, Accuracy: 0.5469
# Batch no: 034, Loss on trainig: 1.7850, Accuracy: 0.5156
# Batch no: 035, Loss on trainig: 1.7052, Accuracy: 0.4688
# Batch no: 036, Loss on trainig: 1.0284, Accuracy: 0.7188
# Batch no: 037, Loss on trainig: 1.6824, Accuracy: 0.5156
# Batch no: 038, Loss on trainig: 1.4194, Accuracy: 0.6406
# Batch no: 039, Loss on trainig: 1.5400, Accuracy: 0.6562
# Batch no: 040, Loss on trainig: 1.5249, Accuracy: 0.5625
# Batch no: 041, Loss on trainig: 1.6657, Accuracy: 0.5625
# Batch no: 042, Loss on trainig: 1.3599, Accuracy: 0.6094
# Batch no: 043, Loss on trainig: 1.2721, Accuracy: 0.6719
# Batch no: 044, Loss on trainig: 1.2636, Accuracy: 0.6250
# Batch no: 045, Loss on trainig: 1.4975, Accuracy: 0.5625
# Batch no: 046, Loss on trainig: 1.9611, Accuracy: 0.4844
# Batch no: 047, Loss on trainig: 1.4911, Accuracy: 0.6094
# Batch no: 048, Loss on trainig: 1.6438, Accuracy: 0.5000
# Batch no: 049, Loss on trainig: 1.7869, Accuracy: 0.5000
# Batch no: 050, Loss on trainig: 1.2324, Accuracy: 0.6250
# Batch no: 051, Loss on trainig: 1.4296, Accuracy: 0.5938
# Batch no: 052, Loss on trainig: 1.5485, Accuracy: 0.4844
# Batch no: 053, Loss on trainig: 1.6387, Accuracy: 0.4844
# Batch no: 054, Loss on trainig: 1.5133, Accuracy: 0.6250
# Batch no: 055, Loss on trainig: 1.4626, Accuracy: 0.5625
# Batch no: 056, Loss on trainig: 1.4700, Accuracy: 0.4844
# Batch no: 057, Loss on trainig: 1.9748, Accuracy: 0.3906
# Batch no: 058, Loss on trainig: 1.8049, Accuracy: 0.5156
# Batch no: 059, Loss on trainig: 1.3996, Accuracy: 0.5469
# Batch no: 060, Loss on trainig: 1.4971, Accuracy: 0.5938
# Batch no: 061, Loss on trainig: 1.3888, Accuracy: 0.5938
# Batch no: 062, Loss on trainig: 1.9464, Accuracy: 0.4688
# Batch no: 063, Loss on trainig: 1.3204, Accuracy: 0.6250
# Batch no: 064, Loss on trainig: 1.9334, Accuracy: 0.5312
# Batch no: 065, Loss on trainig: 1.8100, Accuracy: 0.4844
# Batch no: 066, Loss on trainig: 1.5241, Accuracy: 0.5781
# Batch no: 067, Loss on trainig: 1.3246, Accuracy: 0.5625
# Batch no: 068, Loss on trainig: 1.6146, Accuracy: 0.4688
# Batch no: 069, Loss on trainig: 1.8286, Accuracy: 0.5156
# Batch no: 070, Loss on trainig: 1.2291, Accuracy: 0.6562
# Batch no: 071, Loss on trainig: 1.4968, Accuracy: 0.6094
# Batch no: 072, Loss on trainig: 1.4210, Accuracy: 0.6094
# Batch no: 073, Loss on trainig: 1.4772, Accuracy: 0.5938
# Batch no: 074, Loss on trainig: 1.4267, Accuracy: 0.6094
# Batch no: 075, Loss on trainig: 1.5089, Accuracy: 0.5312
# Batch no: 076, Loss on trainig: 1.6788, Accuracy: 0.6250
# Batch no: 077, Loss on trainig: 1.6517, Accuracy: 0.4688
# Batch no: 078, Loss on trainig: 1.4557, Accuracy: 0.6250
# Batch no: 079, Loss on trainig: 1.7113, Accuracy: 0.5000
# Batch no: 080, Loss on trainig: 1.5261, Accuracy: 0.6250
# Batch no: 081, Loss on trainig: 1.7119, Accuracy: 0.5312
# Batch no: 082, Loss on trainig: 1.6195, Accuracy: 0.5469
# Batch no: 083, Loss on trainig: 1.9699, Accuracy: 0.4844
# Batch no: 084, Loss on trainig: 1.8184, Accuracy: 0.5156
# Batch no: 085, Loss on trainig: 1.6249, Accuracy: 0.5156
# Batch no: 086, Loss on trainig: 1.2513, Accuracy: 0.6719
# Batch no: 087, Loss on trainig: 1.6677, Accuracy: 0.5625
# Batch no: 088, Loss on trainig: 1.4560, Accuracy: 0.5781
# Batch no: 089, Loss on trainig: 1.2779, Accuracy: 0.6562
# Batch no: 090, Loss on trainig: 1.4197, Accuracy: 0.5781
# Batch no: 091, Loss on trainig: 1.2904, Accuracy: 0.6250
# Batch no: 092, Loss on trainig: 1.6132, Accuracy: 0.5000
# Batch no: 093, Loss on trainig: 1.2277, Accuracy: 0.6719
# Batch no: 094, Loss on trainig: 1.8963, Accuracy: 0.5000
# Batch no: 095, Loss on trainig: 1.6701, Accuracy: 0.5625
# Batch no: 096, Loss on trainig: 1.7290, Accuracy: 0.5000
# Batch no: 097, Loss on trainig: 1.4305, Accuracy: 0.6094
# Batch no: 098, Loss on trainig: 1.2442, Accuracy: 0.6875
# Batch no: 099, Loss on trainig: 1.6771, Accuracy: 0.5156
# Batch no: 100, Loss on trainig: 1.3580, Accuracy: 0.5938
# Batch no: 101, Loss on trainig: 1.9624, Accuracy: 0.5469
# Batch no: 102, Loss on trainig: 1.6718, Accuracy: 0.5000
# 18
# Batch no: 000, Loss on trainig: 1.8222, Accuracy: 0.5625
# Batch no: 001, Loss on trainig: 1.6309, Accuracy: 0.4844
# Batch no: 002, Loss on trainig: 1.6139, Accuracy: 0.6094
# Batch no: 003, Loss on trainig: 1.1185, Accuracy: 0.7812
# Batch no: 004, Loss on trainig: 1.3906, Accuracy: 0.5938
# Batch no: 005, Loss on trainig: 1.9785, Accuracy: 0.4688
# Batch no: 006, Loss on trainig: 1.7428, Accuracy: 0.4844
# Batch no: 007, Loss on trainig: 1.9801, Accuracy: 0.5000
# Batch no: 008, Loss on trainig: 1.4936, Accuracy: 0.6250
# Batch no: 009, Loss on trainig: 0.9432, Accuracy: 0.7969
# Batch no: 010, Loss on trainig: 1.6785, Accuracy: 0.5312
# Batch no: 011, Loss on trainig: 1.5939, Accuracy: 0.5312
# Batch no: 012, Loss on trainig: 1.0935, Accuracy: 0.6875
# Batch no: 013, Loss on trainig: 1.2534, Accuracy: 0.6719
# Batch no: 014, Loss on trainig: 1.5475, Accuracy: 0.5312
# Batch no: 015, Loss on trainig: 1.2287, Accuracy: 0.6406
# Batch no: 016, Loss on trainig: 1.7991, Accuracy: 0.5469
# Batch no: 017, Loss on trainig: 1.4412, Accuracy: 0.6406
# Batch no: 018, Loss on trainig: 1.7488, Accuracy: 0.5156
# Batch no: 019, Loss on trainig: 1.5885, Accuracy: 0.5781
# Batch no: 020, Loss on trainig: 1.4684, Accuracy: 0.5781
# Batch no: 021, Loss on trainig: 1.3669, Accuracy: 0.5938
# Batch no: 022, Loss on trainig: 1.7037, Accuracy: 0.5156
# Batch no: 023, Loss on trainig: 1.9274, Accuracy: 0.5156
# Batch no: 024, Loss on trainig: 1.8635, Accuracy: 0.5312
# Batch no: 025, Loss on trainig: 1.3996, Accuracy: 0.5781
# Batch no: 026, Loss on trainig: 1.3459, Accuracy: 0.5781
# Batch no: 027, Loss on trainig: 1.4695, Accuracy: 0.5938
# Batch no: 028, Loss on trainig: 1.3654, Accuracy: 0.5938
# Batch no: 029, Loss on trainig: 1.7558, Accuracy: 0.5312
# Batch no: 030, Loss on trainig: 1.8295, Accuracy: 0.5312
# Batch no: 031, Loss on trainig: 1.5052, Accuracy: 0.5156
# Batch no: 032, Loss on trainig: 1.2793, Accuracy: 0.6719
# Batch no: 033, Loss on trainig: 1.4103, Accuracy: 0.6719
# Batch no: 034, Loss on trainig: 1.7591, Accuracy: 0.5156
# Batch no: 035, Loss on trainig: 1.5057, Accuracy: 0.6094
# Batch no: 036, Loss on trainig: 1.1260, Accuracy: 0.6250
# Batch no: 037, Loss on trainig: 1.4900, Accuracy: 0.6250
# Batch no: 038, Loss on trainig: 1.3146, Accuracy: 0.6719
# Batch no: 039, Loss on trainig: 1.9848, Accuracy: 0.5312
# Batch no: 040, Loss on trainig: 1.1188, Accuracy: 0.6875
# Batch no: 041, Loss on trainig: 1.4378, Accuracy: 0.6094
# Batch no: 042, Loss on trainig: 1.7330, Accuracy: 0.5156
# Batch no: 043, Loss on trainig: 1.4393, Accuracy: 0.5625
# Batch no: 044, Loss on trainig: 1.6305, Accuracy: 0.5000
# Batch no: 045, Loss on trainig: 1.8109, Accuracy: 0.5156
# Batch no: 046, Loss on trainig: 1.5275, Accuracy: 0.5781
# Batch no: 047, Loss on trainig: 1.5179, Accuracy: 0.5312
# Batch no: 048, Loss on trainig: 1.7263, Accuracy: 0.4844
# Batch no: 049, Loss on trainig: 1.8733, Accuracy: 0.5000
# Batch no: 050, Loss on trainig: 1.6677, Accuracy: 0.5000
# Batch no: 051, Loss on trainig: 1.4964, Accuracy: 0.5625
# Batch no: 052, Loss on trainig: 1.3468, Accuracy: 0.6250
# Batch no: 053, Loss on trainig: 1.3940, Accuracy: 0.6406
# Batch no: 054, Loss on trainig: 1.5381, Accuracy: 0.5312
# Batch no: 055, Loss on trainig: 1.7711, Accuracy: 0.5781
# Batch no: 056, Loss on trainig: 1.6351, Accuracy: 0.5469
# Batch no: 057, Loss on trainig: 1.6241, Accuracy: 0.5781
# Batch no: 058, Loss on trainig: 1.3965, Accuracy: 0.6562
# Batch no: 059, Loss on trainig: 1.5851, Accuracy: 0.5312
# Batch no: 060, Loss on trainig: 1.4923, Accuracy: 0.6250
# Batch no: 061, Loss on trainig: 1.6813, Accuracy: 0.5938
# Batch no: 062, Loss on trainig: 1.1729, Accuracy: 0.6406
# Batch no: 063, Loss on trainig: 1.5306, Accuracy: 0.5469
# Batch no: 064, Loss on trainig: 1.6448, Accuracy: 0.5312
# Batch no: 065, Loss on trainig: 1.4804, Accuracy: 0.5156
# Batch no: 066, Loss on trainig: 1.5092, Accuracy: 0.5938
# Batch no: 067, Loss on trainig: 1.2098, Accuracy: 0.6094
# Batch no: 068, Loss on trainig: 1.5197, Accuracy: 0.6094
# Batch no: 069, Loss on trainig: 1.6529, Accuracy: 0.5469
# Batch no: 070, Loss on trainig: 1.5978, Accuracy: 0.5781
# Batch no: 071, Loss on trainig: 1.5032, Accuracy: 0.5625
# Batch no: 072, Loss on trainig: 1.4429, Accuracy: 0.5469
# Batch no: 073, Loss on trainig: 1.6676, Accuracy: 0.5469
# Batch no: 074, Loss on trainig: 1.2297, Accuracy: 0.6562
# Batch no: 075, Loss on trainig: 1.3030, Accuracy: 0.5938
# Batch no: 076, Loss on trainig: 1.1650, Accuracy: 0.6406
# Batch no: 077, Loss on trainig: 1.1055, Accuracy: 0.6094
# Batch no: 078, Loss on trainig: 1.6377, Accuracy: 0.5469
# Batch no: 079, Loss on trainig: 1.4295, Accuracy: 0.6094
# Batch no: 080, Loss on trainig: 1.6414, Accuracy: 0.4844
# Batch no: 081, Loss on trainig: 1.7125, Accuracy: 0.5625
# Batch no: 082, Loss on trainig: 1.4238, Accuracy: 0.5938
# Batch no: 083, Loss on trainig: 1.0692, Accuracy: 0.6719
# Batch no: 084, Loss on trainig: 1.6287, Accuracy: 0.5781
# Batch no: 085, Loss on trainig: 1.3867, Accuracy: 0.6719
# Batch no: 086, Loss on trainig: 1.2969, Accuracy: 0.6719
# Batch no: 087, Loss on trainig: 1.6913, Accuracy: 0.5781
# Batch no: 088, Loss on trainig: 1.7028, Accuracy: 0.5469
# Batch no: 089, Loss on trainig: 1.7510, Accuracy: 0.5000
# Batch no: 090, Loss on trainig: 1.5599, Accuracy: 0.5312
# Batch no: 091, Loss on trainig: 1.4626, Accuracy: 0.5469
# Batch no: 092, Loss on trainig: 1.5430, Accuracy: 0.5000
# Batch no: 093, Loss on trainig: 1.4590, Accuracy: 0.5781
# Batch no: 094, Loss on trainig: 1.3842, Accuracy: 0.5938
# Batch no: 095, Loss on trainig: 1.7277, Accuracy: 0.5156
# Batch no: 096, Loss on trainig: 1.0148, Accuracy: 0.7344
# Batch no: 097, Loss on trainig: 1.4752, Accuracy: 0.5938
# Batch no: 098, Loss on trainig: 1.4881, Accuracy: 0.5469
# Batch no: 099, Loss on trainig: 1.2902, Accuracy: 0.6406
# Batch no: 100, Loss on trainig: 1.2934, Accuracy: 0.6406
# Batch no: 101, Loss on trainig: 1.4573, Accuracy: 0.6250
# Batch no: 102, Loss on trainig: 1.5523, Accuracy: 0.6250
# 19
# Batch no: 000, Loss on trainig: 1.5318, Accuracy: 0.5625
# Batch no: 001, Loss on trainig: 1.2345, Accuracy: 0.6562
# Batch no: 002, Loss on trainig: 1.5396, Accuracy: 0.5156
# Batch no: 003, Loss on trainig: 1.4640, Accuracy: 0.5781
# Batch no: 004, Loss on trainig: 1.4391, Accuracy: 0.6562
# Batch no: 005, Loss on trainig: 1.6377, Accuracy: 0.5625
# Batch no: 006, Loss on trainig: 1.4316, Accuracy: 0.5938
# Batch no: 007, Loss on trainig: 1.5867, Accuracy: 0.5156
# Batch no: 008, Loss on trainig: 1.5878, Accuracy: 0.5000
# Batch no: 009, Loss on trainig: 1.7451, Accuracy: 0.5000
# Batch no: 010, Loss on trainig: 1.6651, Accuracy: 0.5625
# Batch no: 011, Loss on trainig: 1.3396, Accuracy: 0.6406
# Batch no: 012, Loss on trainig: 1.3294, Accuracy: 0.5625
# Batch no: 013, Loss on trainig: 1.1169, Accuracy: 0.7188
# Batch no: 014, Loss on trainig: 1.6791, Accuracy: 0.5312
# Batch no: 015, Loss on trainig: 1.5362, Accuracy: 0.4844
# Batch no: 016, Loss on trainig: 1.4949, Accuracy: 0.6406
# Batch no: 017, Loss on trainig: 1.2744, Accuracy: 0.6094
# Batch no: 018, Loss on trainig: 1.6400, Accuracy: 0.5781
# Batch no: 019, Loss on trainig: 1.4216, Accuracy: 0.5938
# Batch no: 020, Loss on trainig: 1.5734, Accuracy: 0.5469
# Batch no: 021, Loss on trainig: 1.6493, Accuracy: 0.5625
# Batch no: 022, Loss on trainig: 1.5188, Accuracy: 0.5781
# Batch no: 023, Loss on trainig: 1.4343, Accuracy: 0.5625
# Batch no: 024, Loss on trainig: 1.1453, Accuracy: 0.6406
# Batch no: 025, Loss on trainig: 1.3222, Accuracy: 0.6406
# Batch no: 026, Loss on trainig: 1.3996, Accuracy: 0.6094
# Batch no: 027, Loss on trainig: 1.4836, Accuracy: 0.6094
# Batch no: 028, Loss on trainig: 1.4613, Accuracy: 0.6250
# Batch no: 029, Loss on trainig: 1.6151, Accuracy: 0.5938
# Batch no: 030, Loss on trainig: 1.6492, Accuracy: 0.5000
# Batch no: 031, Loss on trainig: 1.5681, Accuracy: 0.5312
# Batch no: 032, Loss on trainig: 1.5166, Accuracy: 0.6094
# Batch no: 033, Loss on trainig: 1.3767, Accuracy: 0.5781
# Batch no: 034, Loss on trainig: 1.2846, Accuracy: 0.6406
# Batch no: 035, Loss on trainig: 1.5536, Accuracy: 0.5156
# Batch no: 036, Loss on trainig: 1.1210, Accuracy: 0.6719
# Batch no: 037, Loss on trainig: 1.5987, Accuracy: 0.5625
# Batch no: 038, Loss on trainig: 1.7976, Accuracy: 0.4688
# Batch no: 039, Loss on trainig: 1.3864, Accuracy: 0.5938
# Batch no: 040, Loss on trainig: 1.2292, Accuracy: 0.6250
# Batch no: 041, Loss on trainig: 1.3274, Accuracy: 0.6094
# Batch no: 042, Loss on trainig: 1.6770, Accuracy: 0.5000
# Batch no: 043, Loss on trainig: 1.4261, Accuracy: 0.6406
# Batch no: 044, Loss on trainig: 1.8579, Accuracy: 0.5312
# Batch no: 045, Loss on trainig: 1.7452, Accuracy: 0.5000
# Batch no: 046, Loss on trainig: 1.9189, Accuracy: 0.5000
# Batch no: 047, Loss on trainig: 1.6095, Accuracy: 0.5938
# Batch no: 048, Loss on trainig: 1.4627, Accuracy: 0.5469
# Batch no: 049, Loss on trainig: 1.2520, Accuracy: 0.6406
# Batch no: 050, Loss on trainig: 1.4845, Accuracy: 0.5469
# Batch no: 051, Loss on trainig: 1.3736, Accuracy: 0.6094
# Batch no: 052, Loss on trainig: 1.1527, Accuracy: 0.6562
# Batch no: 053, Loss on trainig: 1.5023, Accuracy: 0.6094
# Batch no: 054, Loss on trainig: 1.4910, Accuracy: 0.5312
# Batch no: 055, Loss on trainig: 1.2666, Accuracy: 0.5469
# Batch no: 056, Loss on trainig: 1.6086, Accuracy: 0.5938
# Batch no: 057, Loss on trainig: 1.2291, Accuracy: 0.5781
# Batch no: 058, Loss on trainig: 1.6539, Accuracy: 0.6094
# Batch no: 059, Loss on trainig: 1.7375, Accuracy: 0.4531
# Batch no: 060, Loss on trainig: 1.3385, Accuracy: 0.6250
# Batch no: 061, Loss on trainig: 1.6043, Accuracy: 0.5312
# Batch no: 062, Loss on trainig: 1.1624, Accuracy: 0.6406
# Batch no: 063, Loss on trainig: 1.5656, Accuracy: 0.5625
# Batch no: 064, Loss on trainig: 1.9432, Accuracy: 0.5156
# Batch no: 065, Loss on trainig: 1.9567, Accuracy: 0.4688
# Batch no: 066, Loss on trainig: 1.5431, Accuracy: 0.4844
# Batch no: 067, Loss on trainig: 1.5743, Accuracy: 0.5625
# Batch no: 068, Loss on trainig: 1.3340, Accuracy: 0.6406
# Batch no: 069, Loss on trainig: 1.2311, Accuracy: 0.7188
# Batch no: 070, Loss on trainig: 1.4049, Accuracy: 0.6094
# Batch no: 071, Loss on trainig: 1.6875, Accuracy: 0.5469
# Batch no: 072, Loss on trainig: 1.6698, Accuracy: 0.5469
# Batch no: 073, Loss on trainig: 1.0379, Accuracy: 0.6562
# Batch no: 074, Loss on trainig: 1.4494, Accuracy: 0.5312
# Batch no: 075, Loss on trainig: 1.7478, Accuracy: 0.5312
# Batch no: 076, Loss on trainig: 1.6829, Accuracy: 0.4844
# Batch no: 077, Loss on trainig: 1.6137, Accuracy: 0.5469
# Batch no: 078, Loss on trainig: 1.8342, Accuracy: 0.5781
# Batch no: 079, Loss on trainig: 1.6702, Accuracy: 0.5469
# Batch no: 080, Loss on trainig: 1.2169, Accuracy: 0.6562
# Batch no: 081, Loss on trainig: 1.4474, Accuracy: 0.6094
# Batch no: 082, Loss on trainig: 1.6841, Accuracy: 0.5469
# Batch no: 083, Loss on trainig: 1.5508, Accuracy: 0.5625
# Batch no: 084, Loss on trainig: 1.4598, Accuracy: 0.5156
# Batch no: 085, Loss on trainig: 1.4968, Accuracy: 0.5781
# Batch no: 086, Loss on trainig: 1.4472, Accuracy: 0.6250
# Batch no: 087, Loss on trainig: 1.4743, Accuracy: 0.5156
# Batch no: 088, Loss on trainig: 2.2778, Accuracy: 0.3906
# Batch no: 089, Loss on trainig: 1.4263, Accuracy: 0.6250
# Batch no: 090, Loss on trainig: 1.6596, Accuracy: 0.5000
# Batch no: 091, Loss on trainig: 1.0885, Accuracy: 0.7188
# Batch no: 092, Loss on trainig: 1.8328, Accuracy: 0.4844
# Batch no: 093, Loss on trainig: 1.5434, Accuracy: 0.5312
# Batch no: 094, Loss on trainig: 1.2514, Accuracy: 0.6875
# Batch no: 095, Loss on trainig: 1.4848, Accuracy: 0.6094
# Batch no: 096, Loss on trainig: 1.6737, Accuracy: 0.5625
# Batch no: 097, Loss on trainig: 1.6127, Accuracy: 0.5781
# Batch no: 098, Loss on trainig: 1.3163, Accuracy: 0.5938
# Batch no: 099, Loss on trainig: 1.8571, Accuracy: 0.5156
# Batch no: 100, Loss on trainig: 1.7700, Accuracy: 0.4844
# Batch no: 101, Loss on trainig: 1.7700, Accuracy: 0.5938
# Batch no: 102, Loss on trainig: 1.2942, Accuracy: 0.7083

# %%
# Validation - No gradient tracking needed
with torch.no_grad():
 
    # Set to evaluation mode
    model.eval()

    device='cuda'
    # Validation loop
    for j, (inputs, labels) in enumerate(dataloaders['validationloader']):
        inputs = inputs.to(device)
        labels = labels.to(device)
 
        # Forward pass - compute outputs on input data using the model
        outputs = model(inputs)
 
        # Compute loss
        loss = criterion(outputs, labels)
 
        # Compute the total loss for the batch and add it to valid_loss
        valid_loss += loss.item() * inputs.size(0)
 
        # Calculate validation accuracy
        ret, predictions = torch.max(outputs.data, 1)
        correct_counts = predictions.eq(labels.data.view_as(predictions))
 
        # Convert correct_counts to float and then compute the mean
        acc = torch.mean(correct_counts.type(torch.FloatTensor))
 
        # Compute total accuracy in the whole batch and add to valid_acc
        valid_acc += acc.item() * inputs.size(0)
 
        print("Validation Batch number: {:03d}, Validation: Loss: {:.4f}, Accuracy: {:.4f}".format(j, loss.item(), acc.item()*100))
# Out:
# Validation Batch number: 000, Validation: Loss: 0.8974, Accuracy: 76.5625
# Validation Batch number: 001, Validation: Loss: 0.6222, Accuracy: 85.9375
# Validation Batch number: 002, Validation: Loss: 0.9053, Accuracy: 71.8750
# Validation Batch number: 003, Validation: Loss: 1.1371, Accuracy: 70.3125
# Validation Batch number: 004, Validation: Loss: 0.4353, Accuracy: 87.5000
# Validation Batch number: 005, Validation: Loss: 0.9455, Accuracy: 68.7500
# Validation Batch number: 006, Validation: Loss: 0.1981, Accuracy: 95.3125
# Validation Batch number: 007, Validation: Loss: 0.8252, Accuracy: 76.5625
# Validation Batch number: 008, Validation: Loss: 0.2365, Accuracy: 93.7500
# Validation Batch number: 009, Validation: Loss: 0.2204, Accuracy: 96.8750
# Validation Batch number: 010, Validation: Loss: 1.2509, Accuracy: 64.0625
# Validation Batch number: 011, Validation: Loss: 0.8350, Accuracy: 75.0000
# Validation Batch number: 012, Validation: Loss: 1.1205, Accuracy: 72.5490

# %% [markdown]
# ## Testing your network
#
# It's good practice to test your trained network on test data, images the network has never seen either in training or validation. This will give you a good estimate for the model's performance on completely new images. Run the test images through the network and measure the accuracy, the same way you did validation. You should be able to reach around 70% accuracy on the test set if the model has been trained well.

# %%
# Do validation on the test set

def check_accuracy_on_test(testloader,model):  
  device='cuda'
  correct,total = 0,0
  with torch.no_grad():
      model.eval()
      for data in testloader:
          images, labels = data
          images, labels = images.to(device), labels.to(device)
          outputs = model(images)
          _, predicted = torch.max(outputs.data, 1)
          total += labels.size(0)
          correct += (predicted == labels).sum().item()

  print('The Accuracy on the test images is: %d%%' % (100 * correct / total))

check_accuracy_on_test(dataloaders['testloader'],model)
# Out:
# The Accuracy on the test images is: 79%

# %% [markdown]
# ## Save the checkpoint
#
# Now that your network is trained, save the model so you can load it later for making predictions. You probably want to save other things such as the mapping of classes to indices which you get from one of the image datasets: `image_datasets['train'].class_to_idx`. You can attach this to the model as an attribute which makes inference easier later on.
#
# ```model.class_to_idx = image_datasets['train'].class_to_idx```
#
# Remember that you'll want to completely rebuild the model later so you can use it for inference. Make sure to include any information you need in the checkpoint. If you want to load the model and keep training, you'll want to save the number of epochs as well as the optimizer state, `optimizer.state_dict`. You'll likely want to use this trained model in the next part of the project, so best to save it now.

# %%
# TODO: Save the checkpoint 
#The class ImageFolder has an attribute class_to_idx which is a dictionary mapping the name of the class to the index (label).
#So, you can access the classes with data.classes and for each class get the label with data.class_to_idx.

#torch.save: Saves a serialized object to disk. This function uses Python’s pickle utility for serialization.
#Models, tensors, and dictionaries of all kinds of objects can be saved using this function.
#torch.save(model, PATH)
#reference:https://pytorch.org/tutorials/beginner/saving_loading_models.html

model.class_to_idx = image_datasets['training_data'].class_to_idx
torch.save({'structure' :'alexnet',
            'hidden_layer1':120,
             'droupout':0.5,
             'epochs':12,
             'classifier': classifier,
             'state_dict':model.state_dict(),
             'class_to_idx':model.class_to_idx,
             'optimizer_dict':optimizer.state_dict()},
             'checkpoint.pth')

# %% [markdown]
# ## Loading the checkpoint
#
# At this point it's good to write a function that can load a checkpoint and rebuild the model. That way you can come back to this project and keep working on it without having to retrain the network.

# %%
# TODO: Write a function that loads a checkpoint and rebuilds the model

#torch.load: Uses pickle’s unpickling facilities to deserialize pickled object files to memory. 
#This function also facilitates the device to load the data into
#When you call torch.load() on a file which contains GPU tensors, 
#those tensors will be loaded to GPU by default. You can call torch.load(.., map_location='cpu')
# and then load_state_dict() to avoid GPU RAM surge when loading a model checkpoint.
##reference:https://pytorch.org/tutorials/beginner/saving_loading_models.html
def loading_the_checkpoint(path='checkpoint.pth'):
    #load the saved file
    checkpoint = torch.load('checkpoint.pth')
    #download pretrained model
    model=models.vgg16(pretrained=True)
    #to freeze parameters
    for param in model.parameters():
        param.requires_grad = False
    #load from checkpoint
    model.class_to_idx = checkpoint['class_to_idx']
    model.load_state_dict(checkpoint['state_dict'])
    return model

# %% [markdown]
# # Inference for classification
#
# Now you'll write a function to use a trained network for inference. That is, you'll pass an image into the network and predict the class of the flower in the image. Write a function called `predict` that takes an image and a model, then returns the top $K$ most likely classes along with the probabilities. It should look like
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```
#
# First you'll need to handle processing the input image such that it can be used in your network.
#
# ## Image Preprocessing
#
# You'll want to use `PIL` to load the image ([documentation](https://pillow.readthedocs.io/en/latest/reference/Image.html)). It's best to write a function that preprocesses the image so it can be used as input for the model. This function should process the images in the same manner used for training.
#
# First, resize the images where the shortest side is 256 pixels, keeping the aspect ratio. This can be done with the [`thumbnail`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) or [`resize`](http://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail) methods. Then you'll need to crop out the center 224x224 portion of the image.
#
# Color channels of images are typically encoded as integers 0-255, but the model expected floats 0-1. You'll need to convert the values. It's easiest with a Numpy array, which you can get from a PIL image like so `np_image = np.array(pil_image)`.
#
# As before, the network expects the images to be normalized in a specific way. For the means, it's `[0.485, 0.456, 0.406]` and for the standard deviations `[0.229, 0.224, 0.225]`. You'll want to subtract the means from each color channel, then divide by the standard deviation.
#
# And finally, PyTorch expects the color channel to be the first dimension but it's the third dimension in the PIL image and Numpy array. You can reorder dimensions using [`ndarray.transpose`](https://docs.scipy.org/doc/numpy-1.13.0/reference/generated/numpy.ndarray.transpose.html). The color channel needs to be first and retain the order of the other two dimensions.

# %%
# TODO: Process a PIL image for use in a PyTorch model
#Image.thumbnail(size, resample=3)
#https://pillow.readthedocs.io/en/3.1.x/reference/Image.html#PIL.Image.Image.thumbnail
# Crop the center of the image-->.crop((left, top, right, bottom))
#a.transpose().shape = (i[n-1], i[n-2], ... i[1], i[0])
#Refrence on processing the image-->https://stackoverflow.com/questions/55678459/resize-image-in-python
def process_image(image):
    ''' Scales, crops, and normalizes a PIL image for a PyTorch model,
        returns an Numpy array
    '''

    img = PIL.Image.open(image)

    # Get original dimensions
    original_width, original_height = img.size

    # Find shorter size and create settings to crop shortest side to 256
    if original_width < original_height:
        size=[256, 256**600]
    else: 
        size=[256**600, 256]
        
    img.thumbnail(size)
   

    center = original_width/4, original_height/4
    left, top, right, bottom = center[0]-(244/2), center[1]-(244/2), center[0]+(244/2), center[1]+(244/2)
    img = img.crop((left, top, right, bottom))

    numpy_img = np.array(img)/255 

    # Normalize each color channel
    mean = [0.485, 0.456, 0.406]
    std = [0.229, 0.224, 0.225]
    numpy_img = (numpy_img-mean)/std
        
    # Set the color to the first channel
    numpy_img = numpy_img.transpose(2, 0, 1)
    
    return numpy_img

# %% [markdown]
# To check your work, the function below converts a PyTorch tensor and displays it in the notebook. If your `process_image` function works, running the output through this function should return the original image (except for the cropped out portions).

# %%
def imshow(image, ax=None, title=None):
    #img for tensor
    if ax is None:
        fig, ax = plt.subplots()
    
    # PyTorch tensors assume the color channel is the first dimension
    # but matplotlib assumes is the third dimension
    image = image.transpose((1, 2, 0))   
    # Undo preprocessing
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    
    # Image needs to be clipped between 0 and 1 or it looks like noise when displayed
    image = np.clip(image, 0, 1)
    
    ax.imshow(image)
    
    return ax

imshow(process_image("flowers/test/9/image_06413.jpg"))
imshow(process_image("flowers/test/37/image_03734.jpg"))
imshow(process_image("flowers/test/10/image_07090.jpg"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-37-7a99e9c7bbe1> in <module>()
#      19     return ax
#      20
# ---> 21 imshow(process_image("flowers/test/9/image_06413.jpg"))
#      22 imshow(process_image("flowers/test/37/image_03734.jpg"))
#      23 imshow(process_image("flowers/test/10/image_07090.jpg"))
#
# <ipython-input-36-2ce7cbdbf597> in process_image(image)
#       4     '''
#       5
# ----> 6     img = PIL.Image.open(image)
#       7
#       8     # Get original dimensions
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: 'flowers/test/9/image_06413.jpg'

# %% [markdown]
# ## Class Prediction
#
# Once you can get images in the correct format, it's time to write a function for making predictions with your model. A common practice is to predict the top 5 or so (usually called top-$K$) most probable classes. You'll want to calculate the class probabilities then find the $K$ largest values.
#
# To get the top $K$ largest values in a tensor use [`x.topk(k)`](http://pytorch.org/docs/master/torch.html#torch.topk). This method returns both the highest `k` probabilities and the indices of those probabilities corresponding to the classes. You need to convert from these indices to the actual class labels using `class_to_idx` which hopefully you added to the model or from an `ImageFolder` you used to load the data ([see here](#Save-the-checkpoint)). Make sure to invert the dictionary so you get a mapping from index to class as well.
#
# Again, this method should take a path to an image and a model checkpoint, then return the probabilities and classes.
#
# ```python
# probs, classes = predict(image_path, model)
# print(probs)
# print(classes)
# > [ 0.01558163  0.01541934  0.01452626  0.01443549  0.01407339]
# > ['70', '3', '45', '62', '55']
# ```

# %%
def predict(image_path, model, top_k=5):
    ''' Predict the class (or classes) of an image using a trained deep learning model.
    
    image_path: string. Path to image, directly to image and not to folder.
    model: pytorch neural network.
    top_k: integer. The top K classes to be calculated
    
    returns top_probabilities(k), top_labels
    '''
    
    # No need for GPU on this part (just causes problems)
    model.to("cpu")
    
    # Set model to evaluate
    model.eval();

    # Convert image from numpy to torch
    torch_image = torch.from_numpy(np.expand_dims(process_image(image_path), 
                                                  axis=0)).type(torch.FloatTensor).to("cpu")

    # Find probabilities (results) by passing through the function (note the log softmax means that its on a log scale)
    log_probs = model.forward(torch_image)

    # Convert to linear scale
    linear_probs = torch.exp(log_probs)

    # Find the top 5 results
    top_probs, top_labels = linear_probs.topk(top_k)
    
    # Detatch all of the details
    top_probs = np.array(top_probs.detach())[0] # This is not the correct way to do it but the correct way isnt working thanks to cpu/gpu issues so I don't care.
    top_labels = np.array(top_labels.detach())[0]
    
    # Convert to classes
    idx_to_class = {val: key for key, val in    
                                      model.class_to_idx.items()}
    top_labels = [idx_to_class[lab] for lab in top_labels]
    top_flowers = [cat_to_name[lab] for lab in top_labels]
    
    return top_probs, top_labels, top_flowers

# %% [markdown]
# ## Sanity Checking
#
# Now that you can use a trained model for predictions, check to make sure it makes sense. Even if the testing accuracy is high, it's always good to check that there aren't obvious bugs. Use `matplotlib` to plot the probabilities for the top 5 classes as a bar graph, along with the input image. It should look like this:
#
# <img src='assets/inference_example.png' width=300px>
#
# You can convert from the class integer encoding to actual flower names with the `cat_to_name.json` file (should have been loaded earlier in the notebook). To show a PyTorch tensor as an image, use the `imshow` function defined above.

# %%
# TODO: Display an image along with the top 5 classes
# Define image path
image_path = "flowers/test/37/image_03734.jpg"

# Set up plot
plt.figure(figsize = (6,10))
ax = plt.subplot(2,1,1)

# Set up title
flower_num = image_path.split('/')[2]
title_ = cat_to_name[flower_num]

# Plot flower
img = process_image(image_path)
imshow(img, ax, title = title_);

# Make prediction
probs, labs, flowers = predict(image_path, model) 

# Plot bar chart
plt.subplot(2,1,2)
sns.barplot(x=probs, y=flowers, color=sns.color_palette()[0]);
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-39-8c7b3ae95b7c> in <module>()
#      10
#      11 # Plot flower
# ---> 12 img = process_image(image_path)
#      13 imshow(img, ax, title = title_);
#      14
#
# <ipython-input-36-2ce7cbdbf597> in process_image(image)
#       4     '''
#       5
# ----> 6     img = PIL.Image.open(image)
#       7
#       8     # Get original dimensions
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: 'flowers/test/37/image_03734.jpg'

# %%
image_path = "flowers/test/9/image_06413.jpg"
plt.figure(figsize = (6,10))
ax = plt.subplot(2,1,1)
flower_num = image_path.split('/')[2]
title_ = cat_to_name[flower_num]
img = process_image(image_path)
imshow(img, ax, title = title_);
probs, labs, flowers = predict(image_path, model) 
plt.subplot(2,1,2)
sns.barplot(x=probs, y=flowers, color=sns.color_palette()[0]);
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-40-04cc32b68575> in <module>()
#       4 flower_num = image_path.split('/')[2]
#       5 title_ = cat_to_name[flower_num]
# ----> 6 img = process_image(image_path)
#       7 imshow(img, ax, title = title_);
#       8 probs, labs, flowers = predict(image_path, model)
#
# <ipython-input-36-2ce7cbdbf597> in process_image(image)
#       4     '''
#       5
# ----> 6     img = PIL.Image.open(image)
#       7
#       8     # Get original dimensions
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2807
#    2808     if filename:
# -> 2809         fp = builtins.open(filename, "rb")
#    2810         exclusive_fp = True
#    2811
#
# FileNotFoundError: [Errno 2] No such file or directory: 'flowers/test/9/image_06413.jpg'
